# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Check torch version and CUDA status if GPU is enabled.
import torch
print(torch.__version__)
print(torch.cuda.is_available()) # Should return True when GPU is enabled. 

# Imports here
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn, tensor, optim
import torch.nn.functional as F
from torch.autograd import Variable
from torchvision import datasets, transforms
import torchvision.models as models
import seaborn as sns
import time
import PIL
from PIL import Image

device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 2.5.1
# True
# 'cuda'

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

print(data_dir)
print(train_dir)
print(valid_dir)
print(test_dir)
# Out:
# flowers
# flowers/train
# flowers/valid
# flowers/test

# %%
# Define your transforms for the training, validation, and testing sets

# For normalization, values of mean and of standard deviation correspond to those found online as recommended when working
# with PyTorch.
# See https://pytorch.org/vision/0.8/models.html
data_transforms = { 
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],
                             [0.229,0.224,0.225])
    ]),
    'valid': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],
                             [0.229,0.224,0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],
                             [0.229,0.224,0.225])
    ])
}

# Load the datasets with ImageFolder
image_datasets = {
    'train': datasets.ImageFolder(train_dir, transform=data_transforms['train']),
    'valid': datasets.ImageFolder(valid_dir, transform=data_transforms['valid']),
    'test': datasets.ImageFolder(test_dir, transform=data_transforms['test'])
}

# Using the image datasets and the trainforms, define the dataloaders
train_loader = torch.utils.data.DataLoader(image_datasets['train'], batch_size=64, shuffle=True)
validation_loader = torch.utils.data.DataLoader(image_datasets['valid'], batch_size =32)
test_loader = torch.utils.data.DataLoader(image_datasets['test'], batch_size = 32)
#validation_loader = torch.utils.data.DataLoader(image_datasets['valid'], batch_size =64,shuffle = True)
#test_loader = torch.utils.data.DataLoader(image_datasets['test'], batch_size = 64, shuffle = True)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)
    # prints json file
    #print(cat_to_name)
    
no_output_categories = len(cat_to_name)
print("Categories: {}".format(no_output_categories))
# Out:
# Categories: 102

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# Build and train your network

model = models.vgg16(pretrained=True)

for param in model.parameters():
    param.requires_grad = False
    
from collections import OrderedDict

classifier_layers = OrderedDict({
    'fc1' : nn.Linear(25088, 4096),
    'relu1': nn.ReLU(),
    'dropout1': nn.Dropout(0.05),
    'fc2' : nn.Linear(4096, 102),
    'softmax': nn.LogSoftmax(dim=1)
})
    
classifier = nn.Sequential(classifier_layers)

model.classifier = classifier
model.to(device)
# Out:
# C:\Users\pablo\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\pablo\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=4096, bias=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.05, inplace=False)
#     (fc2): Linear(in_features=4096, out_features=102, bias=True)
#     (softmax): LogSoftmax(dim=1)
#   )
# )

# %%
# sets the training hyperparameters

# Before reaching end of 1st epoch during training when configured for 10 epohcs, validation accuracy >70%.
# At the end of the 3rd epoch, validation accuracy ~80% (slightly below).
# At the end of the 3rd epoch, validation accuracy ~83%.
# Increment in  validation accuracy is small for each epoch, so 10 are not really needed.
epochs = 10 # Should be good enough to avoid overfitting
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=0.003)

steps = 0

print_every = 20 # the model trains on 20 batches of images at a time

running_loss = running_accuracy = 0
validation_losses, training_losses = [],[]

start = time.time()

for e in range(epochs):
    batches = 0 # 1 batch = 64 images

    # turns on training mode
    model.train()

    for images,labels in train_loader:
        if (batches == 0) and (e == 0):
            print(f'Epoch {e+1}/{epochs} | Batch {batches} | Time diff from previous batch {0.0:.4f} seconds')
        else:
            print(f'Epoch {e+1}/{epochs} | Batch {batches} | Time diff from previous batch {time.time() - start:.4f} seconds')
        start = time.time() # defines start time
        batches += 1

        # moves images and labels to the GPU
        images,labels = images.to(device),labels.to(device)

        # pushes batch through network
        log_ps = model.forward(images)
        loss = criterion(log_ps,labels)
        loss.backward()
        optimizer.step()

        # calculates the metrics
        ps = torch.exp(log_ps)
        top_ps, top_class = ps.topk(1,dim=1)
        matches = (top_class == labels.view(*top_class.shape)).type(torch.FloatTensor)
        accuracy = matches.mean()

        # resets optimiser gradient and tracks metrics
        optimizer.zero_grad()
        running_loss += loss.item()
        running_accuracy += accuracy.item()

        # runs the model on the validation set every 5 loops
        if batches%print_every == 0:
            end = time.time()
            training_time = end-start
            start = time.time()

            # sets the metrics
            validation_loss = 0
            validation_accuracy = 0

            # turns on evaluation mode, turns off calculation of gradients
            model.eval()
            with torch.no_grad():
                for images,labels in validation_loader:
                    images,labels = images.to(device),labels.to(device)
                    log_ps = model.forward(images)
                    loss = criterion(log_ps,labels)
                    ps = torch.exp(log_ps)
                    top_ps, top_class = ps.topk(1,dim=1)
                    matches = (top_class == \
                                labels.view(*top_class.shape)).type(torch.FloatTensor)
                    accuracy = matches.mean()

                    # tracks validation metrics (test of the model's progress)
                    validation_loss += loss.item()
                    validation_accuracy += accuracy.item()
                
            # tracks training metrics
            end = time.time()
            validation_time = end-start
            validation_losses.append(running_loss/print_every)
            training_losses.append(validation_loss/len(validation_loader))
                
            # prints out metrics
            print(f'Epoch {e+1}/{epochs} | Batch {batches}')
            print(f'Time {validation_time}')
            print(f'Running Training Loss: {running_loss/print_every:.3f}')
            print(f'Running Training Accuracy: {running_accuracy/print_every*100:.2f}%')
            print(f'Validation Loss: {validation_loss/len(validation_loader):.3f}')
            print(f'Validation Accuracy: {validation_accuracy/len(validation_loader)*100:.2f}%')

            # resets the metrics and turns on training mode
            running_loss = running_accuracy = 0
            model.train()
# Out:
# Epoch 1/10 | Batch 0 | Time diff from previous batch 0.0000 seconds
# Epoch 1/10 | Batch 1 | Time diff from previous batch 9.2341 seconds
# Epoch 1/10 | Batch 2 | Time diff from previous batch 8.6055 seconds
# Epoch 1/10 | Batch 3 | Time diff from previous batch 8.6686 seconds
# Epoch 1/10 | Batch 4 | Time diff from previous batch 8.6836 seconds
# Epoch 1/10 | Batch 5 | Time diff from previous batch 8.6510 seconds
# Epoch 1/10 | Batch 6 | Time diff from previous batch 8.6756 seconds
# Epoch 1/10 | Batch 7 | Time diff from previous batch 8.6116 seconds
# Epoch 1/10 | Batch 8 | Time diff from previous batch 8.6443 seconds
# Epoch 1/10 | Batch 9 | Time diff from previous batch 8.7259 seconds
# Epoch 1/10 | Batch 10 | Time diff from previous batch 8.7397 seconds
# Epoch 1/10 | Batch 11 | Time diff from previous batch 8.7746 seconds
# Epoch 1/10 | Batch 12 | Time diff from previous batch 8.6830 seconds
# Epoch 1/10 | Batch 13 | Time diff from previous batch 8.6286 seconds
# Epoch 1/10 | Batch 14 | Time diff from previous batch 8.6339 seconds
# Epoch 1/10 | Batch 15 | Time diff from previous batch 8.7590 seconds
# Epoch 1/10 | Batch 16 | Time diff from previous batch 8.7522 seconds
# Epoch 1/10 | Batch 17 | Time diff from previous batch 8.6784 seconds
# Epoch 1/10 | Batch 18 | Time diff from previous batch 8.5927 seconds
# Epoch 1/10 | Batch 19 | Time diff from previous batch 8.6897 seconds
# Epoch 1/10 | Batch 20
# Time 138.22046375274658
# Running Training Loss: 2.959
# Running Training Accuracy: 32.42%
# Validation Loss: 2.281
# Validation Accuracy: 46.81%
# Epoch 1/10 | Batch 20 | Time diff from previous batch 138.6586 seconds
# Epoch 1/10 | Batch 21 | Time diff from previous batch 8.7020 seconds
# Epoch 1/10 | Batch 22 | Time diff from previous batch 8.6891 seconds
# Epoch 1/10 | Batch 23 | Time diff from previous batch 8.5971 seconds
# Epoch 1/10 | Batch 24 | Time diff from previous batch 8.6427 seconds
# Epoch 1/10 | Batch 25 | Time diff from previous batch 8.6095 seconds
# Epoch 1/10 | Batch 26 | Time diff from previous batch 8.5000 seconds
# Epoch 1/10 | Batch 27 | Time diff from previous batch 8.5496 seconds
# Epoch 1/10 | Batch 28 | Time diff from previous batch 8.5024 seconds
# Epoch 1/10 | Batch 29 | Time diff from previous batch 8.5344 seconds
# Epoch 1/10 | Batch 30 | Time diff from previous batch 8.5303 seconds
# Epoch 1/10 | Batch 31 | Time diff from previous batch 8.5275 seconds
# Epoch 1/10 | Batch 32 | Time diff from previous batch 8.5441 seconds
# Epoch 1/10 | Batch 33 | Time diff from previous batch 8.5197 seconds
# Epoch 1/10 | Batch 34 | Time diff from previous batch 8.5721 seconds
# Epoch 1/10 | Batch 35 | Time diff from previous batch 8.5095 seconds
# Epoch 1/10 | Batch 36 | Time diff from previous batch 8.5411 seconds
# Epoch 1/10 | Batch 37 | Time diff from previous batch 8.5083 seconds
# Epoch 1/10 | Batch 38 | Time diff from previous batch 8.5389 seconds
# Epoch 1/10 | Batch 39 | Time diff from previous batch 8.5556 seconds
# Epoch 1/10 | Batch 40
# Time 135.83787941932678
# Running Training Loss: 2.263
# Running Training Accuracy: 45.08%
# Validation Loss: 1.412
# Validation Accuracy: 61.16%
# Epoch 1/10 | Batch 40 | Time diff from previous batch 136.3380 seconds
# Epoch 1/10 | Batch 41 | Time diff from previous batch 8.5635 seconds
# Epoch 1/10 | Batch 42 | Time diff from previous batch 8.5668 seconds
# Epoch 1/10 | Batch 43 | Time diff from previous batch 8.5334 seconds
# Epoch 1/10 | Batch 44 | Time diff from previous batch 8.5735 seconds
# Epoch 1/10 | Batch 45 | Time diff from previous batch 8.5970 seconds
# Epoch 1/10 | Batch 46 | Time diff from previous batch 8.7624 seconds
# Epoch 1/10 | Batch 47 | Time diff from previous batch 8.5879 seconds
# Epoch 1/10 | Batch 48 | Time diff from previous batch 9.1079 seconds
# Epoch 1/10 | Batch 49 | Time diff from previous batch 8.6224 seconds
# Epoch 1/10 | Batch 50 | Time diff from previous batch 8.5920 seconds
# Epoch 1/10 | Batch 51 | Time diff from previous batch 8.7053 seconds
# Epoch 1/10 | Batch 52 | Time diff from previous batch 8.6721 seconds
# Epoch 1/10 | Batch 53 | Time diff from previous batch 8.6387 seconds
# Epoch 1/10 | Batch 54 | Time diff from previous batch 8.5990 seconds
# Epoch 1/10 | Batch 55 | Time diff from previous batch 9.0131 seconds
# Epoch 1/10 | Batch 56 | Time diff from previous batch 8.8387 seconds
# Epoch 1/10 | Batch 57 | Time diff from previous batch 8.9535 seconds
# Epoch 1/10 | Batch 58 | Time diff from previous batch 8.9415 seconds
# Epoch 1/10 | Batch 59 | Time diff from previous batch 8.8789 seconds
# Epoch 1/10 | Batch 60
# Time 138.38042569160461
# Running Training Loss: 1.866
# Running Training Accuracy: 52.89%
# Validation Loss: 1.369
# Validation Accuracy: 63.78%
# Epoch 1/10 | Batch 60 | Time diff from previous batch 138.8442 seconds
# Epoch 1/10 | Batch 61 | Time diff from previous batch 8.6152 seconds
# Epoch 1/10 | Batch 62 | Time diff from previous batch 8.5762 seconds
# Epoch 1/10 | Batch 63 | Time diff from previous batch 8.5990 seconds
# Epoch 1/10 | Batch 64 | Time diff from previous batch 8.6122 seconds
# Epoch 1/10 | Batch 65 | Time diff from previous batch 8.7448 seconds
# Epoch 1/10 | Batch 102 | Time diff from previous batch 8.3452 seconds
# Epoch 2/10 | Batch 0 | Time diff from previous batch 5.6197 seconds
# Epoch 2/10 | Batch 1 | Time diff from previous batch 8.6088 seconds
# Epoch 2/10 | Batch 2 | Time diff from previous batch 8.6517 seconds
# Epoch 2/10 | Batch 3 | Time diff from previous batch 8.6630 seconds
# Epoch 2/10 | Batch 4 | Time diff from previous batch 8.5915 seconds
# Epoch 2/10 | Batch 5 | Time diff from previous batch 8.5498 seconds
# Epoch 2/10 | Batch 6 | Time diff from previous batch 8.5578 seconds
# Epoch 2/10 | Batch 7 | Time diff from previous batch 8.6046 seconds
# Epoch 2/10 | Batch 8 | Time diff from previous batch 8.5386 seconds
# Epoch 2/10 | Batch 9 | Time diff from previous batch 8.5376 seconds
# Epoch 2/10 | Batch 10 | Time diff from previous batch 8.5390 seconds
# Epoch 2/10 | Batch 11 | Time diff from previous batch 8.6232 seconds
# Epoch 2/10 | Batch 12 | Time diff from previous batch 8.6436 seconds
# Epoch 2/10 | Batch 13 | Time diff from previous batch 8.5636 seconds
# Epoch 2/10 | Batch 14 | Time diff from previous batch 8.7033 seconds
# Epoch 2/10 | Batch 15 | Time diff from previous batch 8.6295 seconds
# Epoch 2/10 | Batch 16 | Time diff from previous batch 8.7181 seconds
# Epoch 2/10 | Batch 17 | Time diff from previous batch 8.7261 seconds
# Epoch 2/10 | Batch 18 | Time diff from previous batch 8.5574 seconds
# Epoch 2/10 | Batch 19 | Time diff from previous batch 8.5766 seconds
# Epoch 2/10 | Batch 20
# Time 137.62801504135132
# Running Training Loss: 1.727
# Running Training Accuracy: 70.03%
# Validation Loss: 0.910
# Validation Accuracy: 74.09%
# Epoch 2/10 | Batch 20 | Time diff from previous batch 137.9975 seconds
# Epoch 2/10 | Batch 21 | Time diff from previous batch 8.5815 seconds
# Epoch 2/10 | Batch 22 | Time diff from previous batch 8.6567 seconds
# Epoch 2/10 | Batch 23 | Time diff from previous batch 8.5953 seconds
# Epoch 2/10 | Batch 24 | Time diff from previous batch 8.5973 seconds
# Epoch 2/10 | Batch 25 | Time diff from previous batch 8.5671 seconds
# Epoch 2/10 | Batch 26 | Time diff from previous batch 8.6374 seconds
# Epoch 2/10 | Batch 27 | Time diff from previous batch 8.6274 seconds
# Epoch 2/10 | Batch 28 | Time diff from previous batch 8.5824 seconds
# Epoch 2/10 | Batch 29 | Time diff from previous batch 8.6286 seconds
# Epoch 2/10 | Batch 30 | Time diff from previous batch 8.6546 seconds
# Epoch 2/10 | Batch 31 | Time diff from previous batch 8.6167 seconds
# Epoch 2/10 | Batch 32 | Time diff from previous batch 8.6762 seconds
# Epoch 2/10 | Batch 33 | Time diff from previous batch 8.6639 seconds
# Epoch 2/10 | Batch 34 | Time diff from previous batch 9.0180 seconds
# Epoch 2/10 | Batch 35 | Time diff from previous batch 8.6567 seconds
# Epoch 2/10 | Batch 36 | Time diff from previous batch 8.9254 seconds
# Epoch 2/10 | Batch 37 | Time diff from previous batch 8.5803 seconds
# Epoch 2/10 | Batch 38 | Time diff from previous batch 8.5510 seconds
# Epoch 2/10 | Batch 39 | Time diff from previous batch 8.6019 seconds
# Epoch 2/10 | Batch 40
# Time 137.18228816986084
# Running Training Loss: 1.428
# Running Training Accuracy: 65.31%
# Validation Loss: 1.113
# Validation Accuracy: 73.76%
# Epoch 2/10 | Batch 40 | Time diff from previous batch 137.5368 seconds
# Epoch 2/10 | Batch 41 | Time diff from previous batch 8.6759 seconds
# Epoch 2/10 | Batch 42 | Time diff from previous batch 8.5918 seconds
# Epoch 2/10 | Batch 43 | Time diff from previous batch 8.5652 seconds
# Epoch 2/10 | Batch 44 | Time diff from previous batch 8.6387 seconds
# Epoch 2/10 | Batch 45 | Time diff from previous batch 8.7677 seconds
# Epoch 2/10 | Batch 46 | Time diff from previous batch 8.6303 seconds
# Epoch 2/10 | Batch 47 | Time diff from previous batch 8.5597 seconds
# Epoch 2/10 | Batch 48 | Time diff from previous batch 8.6629 seconds
# Epoch 2/10 | Batch 49 | Time diff from previous batch 8.5917 seconds
# Epoch 2/10 | Batch 50 | Time diff from previous batch 8.5957 seconds
# Epoch 2/10 | Batch 51 | Time diff from previous batch 8.5678 seconds
# Epoch 2/10 | Batch 52 | Time diff from previous batch 8.6473 seconds
# Epoch 2/10 | Batch 53 | Time diff from previous batch 8.5986 seconds
# Epoch 2/10 | Batch 54 | Time diff from previous batch 8.7205 seconds
# Epoch 2/10 | Batch 55 | Time diff from previous batch 8.6775 seconds
# Epoch 2/10 | Batch 56 | Time diff from previous batch 8.6284 seconds
# Epoch 2/10 | Batch 57 | Time diff from previous batch 8.5677 seconds
# Epoch 2/10 | Batch 58 | Time diff from previous batch 8.6334 seconds
# Epoch 2/10 | Batch 59 | Time diff from previous batch 8.6107 seconds
# Epoch 2/10 | Batch 60
# Time 137.70528292655945
# Running Training Loss: 1.395
# Running Training Accuracy: 66.25%
# Validation Loss: 1.070
# Validation Accuracy: 72.10%
# Epoch 2/10 | Batch 60 | Time diff from previous batch 138.0646 seconds
# Epoch 2/10 | Batch 61 | Time diff from previous batch 8.5927 seconds
# Epoch 2/10 | Batch 62 | Time diff from previous batch 8.5480 seconds
# Epoch 2/10 | Batch 63 | Time diff from previous batch 8.5877 seconds
# Epoch 2/10 | Batch 64 | Time diff from previous batch 8.7138 seconds
# Epoch 2/10 | Batch 65 | Time diff from previous batch 8.5768 seconds
# Epoch 2/10 | Batch 66 | Time diff from previous batch 8.6511 seconds
# Epoch 2/10 | Batch 67 | Time diff from previous batch 8.6324 seconds
# Epoch 2/10 | Batch 68 | Time diff from previous batch 8.5761 seconds
# Epoch 2/10 | Batch 69 | Time diff from previous batch 8.5493 seconds
# Epoch 2/10 | Batch 70 | Time diff from previous batch 8.6938 seconds
# Epoch 2/10 | Batch 71 | Time diff from previous batch 8.6504 seconds
# Epoch 2/10 | Batch 72 | Time diff from previous batch 8.6032 seconds
# Epoch 2/10 | Batch 73 | Time diff from previous batch 8.6907 seconds
# Epoch 2/10 | Batch 74 | Time diff from previous batch 8.6560 seconds
# Epoch 2/10 | Batch 75 | Time diff from previous batch 8.6017 seconds
# Epoch 2/10 | Batch 76 | Time diff from previous batch 8.6621 seconds
# Epoch 2/10 | Batch 77 | Time diff from previous batch 8.6495 seconds
# Epoch 2/10 | Batch 78 | Time diff from previous batch 8.6190 seconds
# Epoch 2/10 | Batch 79 | Time diff from previous batch 8.5762 seconds
# Epoch 2/10 | Batch 80
# Time 137.20767068862915
# Running Training Loss: 1.388
# Running Training Accuracy: 65.23%
# Validation Loss: 0.828
# Validation Accuracy: 77.34%
# Epoch 2/10 | Batch 80 | Time diff from previous batch 137.5749 seconds
# Epoch 2/10 | Batch 81 | Time diff from previous batch 8.6265 seconds
# Epoch 2/10 | Batch 82 | Time diff from previous batch 8.5756 seconds
# Epoch 2/10 | Batch 83 | Time diff from previous batch 8.6832 seconds
# Epoch 2/10 | Batch 84 | Time diff from previous batch 8.5623 seconds
# Epoch 2/10 | Batch 85 | Time diff from previous batch 8.6072 seconds
# Epoch 2/10 | Batch 86 | Time diff from previous batch 8.5345 seconds
# Epoch 2/10 | Batch 87 | Time diff from previous batch 8.5928 seconds
# Epoch 2/10 | Batch 88 | Time diff from previous batch 8.7054 seconds
# Epoch 2/10 | Batch 89 | Time diff from previous batch 8.6514 seconds
# Epoch 2/10 | Batch 90 | Time diff from previous batch 8.6487 seconds
# Epoch 2/10 | Batch 91 | Time diff from previous batch 8.5726 seconds
# Epoch 2/10 | Batch 92 | Time diff from previous batch 8.6470 seconds
# Epoch 2/10 | Batch 93 | Time diff from previous batch 8.7083 seconds
# Epoch 2/10 | Batch 94 | Time diff from previous batch 8.6106 seconds
# Epoch 2/10 | Batch 95 | Time diff from previous batch 8.6039 seconds
# Epoch 2/10 | Batch 96 | Time diff from previous batch 8.6081 seconds
# Epoch 2/10 | Batch 97 | Time diff from previous batch 8.5402 seconds
# Epoch 2/10 | Batch 98 | Time diff from previous batch 8.6164 seconds
# Epoch 2/10 | Batch 99 | Time diff from previous batch 8.6253 seconds
# Epoch 2/10 | Batch 100
# Time 137.1887092590332
# Running Training Loss: 1.361
# Running Training Accuracy: 65.78%
# Validation Loss: 0.787
# Validation Accuracy: 77.51%
# Epoch 2/10 | Batch 100 | Time diff from previous batch 137.5454 seconds
# Epoch 2/10 | Batch 101 | Time diff from previous batch 8.5732 seconds
# Epoch 2/10 | Batch 102 | Time diff from previous batch 8.4238 seconds
# Epoch 3/10 | Batch 0 | Time diff from previous batch 5.5796 seconds
# Epoch 3/10 | Batch 1 | Time diff from previous batch 8.5675 seconds
# Epoch 3/10 | Batch 2 | Time diff from previous batch 8.6183 seconds
# Epoch 3/10 | Batch 3 | Time diff from previous batch 8.5677 seconds
# Epoch 3/10 | Batch 4 | Time diff from previous batch 8.5295 seconds
# Epoch 3/10 | Batch 5 | Time diff from previous batch 8.6209 seconds
# Epoch 3/10 | Batch 6 | Time diff from previous batch 8.6334 seconds
# Epoch 3/10 | Batch 7 | Time diff from previous batch 8.5431 seconds
# Epoch 3/10 | Batch 8 | Time diff from previous batch 8.5688 seconds
# Epoch 3/10 | Batch 9 | Time diff from previous batch 8.6023 seconds
# Epoch 3/10 | Batch 10 | Time diff from previous batch 8.7463 seconds
# Epoch 3/10 | Batch 11 | Time diff from previous batch 8.7350 seconds
# Epoch 3/10 | Batch 12 | Time diff from previous batch 8.7094 seconds
# Epoch 3/10 | Batch 13 | Time diff from previous batch 8.6196 seconds
# Epoch 3/10 | Batch 14 | Time diff from previous batch 8.5627 seconds
# Epoch 3/10 | Batch 15 | Time diff from previous batch 8.5426 seconds
# Epoch 3/10 | Batch 16 | Time diff from previous batch 8.5067 seconds
# Epoch 3/10 | Batch 17 | Time diff from previous batch 8.5255 seconds
# Epoch 3/10 | Batch 18 | Time diff from previous batch 8.6451 seconds
# Epoch 3/10 | Batch 19 | Time diff from previous batch 8.5956 seconds
# Epoch 3/10 | Batch 20
# Time 135.4883110523224
# Running Training Loss: 1.424
# Running Training Accuracy: 77.89%
# Validation Loss: 0.787
# Validation Accuracy: 77.70%
# Epoch 3/10 | Batch 20 | Time diff from previous batch 135.8911 seconds
# Epoch 3/10 | Batch 21 | Time diff from previous batch 8.4804 seconds
# Epoch 3/10 | Batch 22 | Time diff from previous batch 8.5257 seconds
# Epoch 3/10 | Batch 23 | Time diff from previous batch 8.5043 seconds
# Epoch 3/10 | Batch 24 | Time diff from previous batch 8.5147 seconds
# Epoch 3/10 | Batch 25 | Time diff from previous batch 8.5268 seconds
# Epoch 3/10 | Batch 26 | Time diff from previous batch 8.5443 seconds
# Epoch 3/10 | Batch 27 | Time diff from previous batch 8.4840 seconds
# Epoch 3/10 | Batch 28 | Time diff from previous batch 8.5221 seconds
# Epoch 3/10 | Batch 29 | Time diff from previous batch 8.5398 seconds
# Epoch 3/10 | Batch 30 | Time diff from previous batch 8.5542 seconds
# Epoch 3/10 | Batch 31 | Time diff from previous batch 8.5062 seconds
# Epoch 3/10 | Batch 32 | Time diff from previous batch 8.4568 seconds
# Epoch 3/10 | Batch 33 | Time diff from previous batch 8.5235 seconds
# Epoch 3/10 | Batch 34 | Time diff from previous batch 8.5812 seconds
# Epoch 3/10 | Batch 35 | Time diff from previous batch 8.5415 seconds
# Epoch 3/10 | Batch 36 | Time diff from previous batch 8.5115 seconds
# Epoch 3/10 | Batch 37 | Time diff from previous batch 8.5185 seconds
# Epoch 3/10 | Batch 38 | Time diff from previous batch 8.4864 seconds
# Epoch 3/10 | Batch 39 | Time diff from previous batch 8.5451 seconds
# Epoch 3/10 | Batch 40
# Time 136.43628549575806
# Running Training Loss: 1.219
# Running Training Accuracy: 68.28%
# Validation Loss: 0.799
# Validation Accuracy: 79.86%
# Epoch 3/10 | Batch 40 | Time diff from previous batch 136.8067 seconds
# Epoch 3/10 | Batch 41 | Time diff from previous batch 8.4873 seconds
# Epoch 3/10 | Batch 42 | Time diff from previous batch 8.6460 seconds
# Epoch 3/10 | Batch 43 | Time diff from previous batch 8.5536 seconds
# Epoch 3/10 | Batch 44 | Time diff from previous batch 8.5782 seconds
# Epoch 3/10 | Batch 45 | Time diff from previous batch 8.5057 seconds
# Epoch 3/10 | Batch 46 | Time diff from previous batch 8.5843 seconds
# Epoch 3/10 | Batch 47 | Time diff from previous batch 8.5195 seconds
# Epoch 3/10 | Batch 48 | Time diff from previous batch 8.6467 seconds
# Epoch 3/10 | Batch 49 | Time diff from previous batch 8.5406 seconds
# Epoch 3/10 | Batch 50 | Time diff from previous batch 8.5695 seconds
# Epoch 3/10 | Batch 51 | Time diff from previous batch 8.6318 seconds
# Epoch 3/10 | Batch 52 | Time diff from previous batch 8.5703 seconds
# Epoch 3/10 | Batch 53 | Time diff from previous batch 8.5433 seconds
# Epoch 3/10 | Batch 54 | Time diff from previous batch 8.7253 seconds
# Epoch 3/10 | Batch 55 | Time diff from previous batch 8.5449 seconds
# Epoch 3/10 | Batch 56 | Time diff from previous batch 8.5591 seconds
# Epoch 3/10 | Batch 57 | Time diff from previous batch 8.6130 seconds
# Epoch 3/10 | Batch 58 | Time diff from previous batch 8.5207 seconds
# Epoch 3/10 | Batch 59 | Time diff from previous batch 8.5929 seconds
# Epoch 3/10 | Batch 60
# Time 136.84095454216003
# Running Training Loss: 1.239
# Running Training Accuracy: 67.34%
# Validation Loss: 0.815
# Validation Accuracy: 79.09%
# Epoch 3/10 | Batch 60 | Time diff from previous batch 137.1691 seconds
# Epoch 3/10 | Batch 61 | Time diff from previous batch 8.5577 seconds
# Epoch 3/10 | Batch 62 | Time diff from previous batch 8.5771 seconds
# Epoch 3/10 | Batch 63 | Time diff from previous batch 8.6271 seconds
# Epoch 3/10 | Batch 64 | Time diff from previous batch 8.5482 seconds
# Epoch 3/10 | Batch 65 | Time diff from previous batch 8.5521 seconds
# Epoch 3/10 | Batch 66 | Time diff from previous batch 8.7419 seconds
# Epoch 3/10 | Batch 67 | Time diff from previous batch 8.5588 seconds
# Epoch 3/10 | Batch 68 | Time diff from previous batch 8.5814 seconds
# Epoch 3/10 | Batch 69 | Time diff from previous batch 8.5553 seconds
# Epoch 3/10 | Batch 70 | Time diff from previous batch 8.5795 seconds
# Epoch 3/10 | Batch 71 | Time diff from previous batch 8.5944 seconds
# Epoch 3/10 | Batch 72 | Time diff from previous batch 8.5687 seconds
# Epoch 3/10 | Batch 73 | Time diff from previous batch 8.6504 seconds
# Epoch 3/10 | Batch 74 | Time diff from previous batch 8.4940 seconds
# Epoch 3/10 | Batch 75 | Time diff from previous batch 8.5387 seconds
# Epoch 3/10 | Batch 76 | Time diff from previous batch 8.6390 seconds
# Epoch 3/10 | Batch 77 | Time diff from previous batch 8.6426 seconds
# Epoch 3/10 | Batch 78 | Time diff from previous batch 8.5398 seconds
# Epoch 3/10 | Batch 79 | Time diff from previous batch 8.5783 seconds
# Epoch 3/10 | Batch 80
# Time 137.09657621383667
# Running Training Loss: 1.200
# Running Training Accuracy: 69.22%
# Validation Loss: 0.790
# Validation Accuracy: 79.71%
# Epoch 3/10 | Batch 80 | Time diff from previous batch 137.4388 seconds
# Epoch 3/10 | Batch 81 | Time diff from previous batch 8.5936 seconds
# Epoch 3/10 | Batch 82 | Time diff from previous batch 8.6699 seconds
# Epoch 3/10 | Batch 83 | Time diff from previous batch 8.6393 seconds
# Epoch 3/10 | Batch 84 | Time diff from previous batch 8.5296 seconds
# Epoch 3/10 | Batch 85 | Time diff from previous batch 8.5390 seconds
# Epoch 3/10 | Batch 86 | Time diff from previous batch 8.6270 seconds
# Epoch 3/10 | Batch 87 | Time diff from previous batch 8.5980 seconds
# Epoch 3/10 | Batch 88 | Time diff from previous batch 8.6301 seconds
# Epoch 3/10 | Batch 89 | Time diff from previous batch 8.7925 seconds
# Epoch 3/10 | Batch 90 | Time diff from previous batch 8.8065 seconds
# Epoch 3/10 | Batch 91 | Time diff from previous batch 8.5877 seconds
# Epoch 3/10 | Batch 92 | Time diff from previous batch 8.7332 seconds
# Epoch 3/10 | Batch 93 | Time diff from previous batch 8.6546 seconds
# Epoch 3/10 | Batch 94 | Time diff from previous batch 8.5762 seconds
# Epoch 3/10 | Batch 95 | Time diff from previous batch 8.6555 seconds
# Epoch 3/10 | Batch 96 | Time diff from previous batch 8.5986 seconds
# Epoch 3/10 | Batch 97 | Time diff from previous batch 8.5744 seconds
# Epoch 3/10 | Batch 98 | Time diff from previous batch 8.5814 seconds
# Epoch 3/10 | Batch 99 | Time diff from previous batch 8.5737 seconds
# Epoch 3/10 | Batch 100
# Time 138.10178542137146
# Running Training Loss: 1.316
# Running Training Accuracy: 67.66%
# Validation Loss: 0.788
# Validation Accuracy: 79.62%
# Epoch 3/10 | Batch 100 | Time diff from previous batch 138.4344 seconds
# Epoch 3/10 | Batch 101 | Time diff from previous batch 8.6223 seconds
# Epoch 3/10 | Batch 102 | Time diff from previous batch 8.4318 seconds
# Epoch 4/10 | Batch 0 | Time diff from previous batch 5.5709 seconds
# Epoch 4/10 | Batch 1 | Time diff from previous batch 8.6749 seconds
# Epoch 4/10 | Batch 2 | Time diff from previous batch 8.6483 seconds
# Epoch 4/10 | Batch 3 | Time diff from previous batch 8.7134 seconds
# Epoch 4/10 | Batch 4 | Time diff from previous batch 8.5829 seconds
# Epoch 4/10 | Batch 5 | Time diff from previous batch 8.6067 seconds
# Epoch 4/10 | Batch 6 | Time diff from previous batch 8.6327 seconds
# Epoch 4/10 | Batch 7 | Time diff from previous batch 8.5979 seconds
# Epoch 4/10 | Batch 8 | Time diff from previous batch 8.6868 seconds
# Epoch 4/10 | Batch 9 | Time diff from previous batch 8.5313 seconds
# Epoch 4/10 | Batch 10 | Time diff from previous batch 8.5421 seconds
# Epoch 4/10 | Batch 11 | Time diff from previous batch 8.5199 seconds
# Epoch 4/10 | Batch 12 | Time diff from previous batch 8.6042 seconds
# Epoch 4/10 | Batch 13 | Time diff from previous batch 8.6909 seconds
# Epoch 4/10 | Batch 14 | Time diff from previous batch 9.0243 seconds
# Epoch 4/10 | Batch 15 | Time diff from previous batch 8.8041 seconds
# Epoch 4/10 | Batch 16 | Time diff from previous batch 8.5457 seconds
# Epoch 4/10 | Batch 17 | Time diff from previous batch 8.4835 seconds
# Epoch 4/10 | Batch 18 | Time diff from previous batch 8.5453 seconds
# Epoch 4/10 | Batch 19 | Time diff from previous batch 8.4832 seconds
# Epoch 4/10 | Batch 20
# Time 139.409423828125
# Running Training Loss: 1.318
# Running Training Accuracy: 82.58%
# Validation Loss: 0.823
# Validation Accuracy: 79.74%
# Epoch 4/10 | Batch 20 | Time diff from previous batch 139.8238 seconds
# Epoch 4/10 | Batch 21 | Time diff from previous batch 8.8991 seconds
# Epoch 4/10 | Batch 22 | Time diff from previous batch 8.6830 seconds
# Epoch 4/10 | Batch 23 | Time diff from previous batch 8.7112 seconds
# Epoch 4/10 | Batch 24 | Time diff from previous batch 8.5416 seconds
# Epoch 4/10 | Batch 25 | Time diff from previous batch 8.5160 seconds
# Epoch 4/10 | Batch 26 | Time diff from previous batch 8.5630 seconds
# Epoch 4/10 | Batch 27 | Time diff from previous batch 8.5783 seconds
# Epoch 4/10 | Batch 28 | Time diff from previous batch 8.5849 seconds
# Epoch 4/10 | Batch 29 | Time diff from previous batch 8.5590 seconds
# Epoch 4/10 | Batch 30 | Time diff from previous batch 8.4981 seconds
# Epoch 4/10 | Batch 31 | Time diff from previous batch 8.5425 seconds
# Epoch 4/10 | Batch 32 | Time diff from previous batch 8.5108 seconds
# Epoch 4/10 | Batch 33 | Time diff from previous batch 8.5455 seconds
# Epoch 4/10 | Batch 34 | Time diff from previous batch 8.5259 seconds
# Epoch 4/10 | Batch 35 | Time diff from previous batch 8.6059 seconds
# Epoch 4/10 | Batch 36 | Time diff from previous batch 8.5546 seconds
# Epoch 4/10 | Batch 37 | Time diff from previous batch 8.5613 seconds
# Epoch 4/10 | Batch 38 | Time diff from previous batch 8.5666 seconds
# Epoch 4/10 | Batch 39 | Time diff from previous batch 8.5815 seconds
# Epoch 4/10 | Batch 40
# Time 137.35187005996704
# Running Training Loss: 1.121
# Running Training Accuracy: 71.56%
# Validation Loss: 0.692
# Validation Accuracy: 81.40%
# Epoch 4/10 | Batch 40 | Time diff from previous batch 137.7619 seconds
# Epoch 4/10 | Batch 41 | Time diff from previous batch 8.6294 seconds
# Epoch 4/10 | Batch 42 | Time diff from previous batch 8.6150 seconds
# Epoch 4/10 | Batch 43 | Time diff from previous batch 8.5978 seconds
# Epoch 4/10 | Batch 44 | Time diff from previous batch 8.6324 seconds
# Epoch 4/10 | Batch 45 | Time diff from previous batch 8.5914 seconds
# Epoch 4/10 | Batch 46 | Time diff from previous batch 8.5861 seconds
# Epoch 4/10 | Batch 47 | Time diff from previous batch 8.6732 seconds
# Epoch 4/10 | Batch 48 | Time diff from previous batch 8.5790 seconds
# Epoch 4/10 | Batch 49 | Time diff from previous batch 8.6039 seconds
# Epoch 4/10 | Batch 50 | Time diff from previous batch 8.5546 seconds
# Epoch 4/10 | Batch 51 | Time diff from previous batch 8.6061 seconds
# Epoch 4/10 | Batch 52 | Time diff from previous batch 8.5619 seconds
# Epoch 4/10 | Batch 53 | Time diff from previous batch 8.5729 seconds
# Epoch 4/10 | Batch 54 | Time diff from previous batch 8.5907 seconds
# Epoch 4/10 | Batch 55 | Time diff from previous batch 8.6211 seconds
# Epoch 4/10 | Batch 56 | Time diff from previous batch 8.5804 seconds
# Epoch 4/10 | Batch 57 | Time diff from previous batch 8.5651 seconds
# Epoch 4/10 | Batch 58 | Time diff from previous batch 8.5965 seconds
# Epoch 4/10 | Batch 59 | Time diff from previous batch 8.6475 seconds
# Epoch 4/10 | Batch 60
# Time 139.2817621231079
# Running Training Loss: 1.151
# Running Training Accuracy: 71.80%
# Validation Loss: 0.820
# Validation Accuracy: 80.56%
# Epoch 4/10 | Batch 60 | Time diff from previous batch 139.6813 seconds
# Epoch 4/10 | Batch 61 | Time diff from previous batch 8.8285 seconds
# Epoch 4/10 | Batch 62 | Time diff from previous batch 8.6389 seconds
# Epoch 4/10 | Batch 63 | Time diff from previous batch 8.6572 seconds
# Epoch 4/10 | Batch 64 | Time diff from previous batch 8.6621 seconds
# Epoch 4/10 | Batch 65 | Time diff from previous batch 8.5882 seconds
# Epoch 4/10 | Batch 66 | Time diff from previous batch 8.6615 seconds
# Epoch 4/10 | Batch 67 | Time diff from previous batch 8.6457 seconds
# Epoch 4/10 | Batch 68 | Time diff from previous batch 8.6738 seconds
# Epoch 4/10 | Batch 69 | Time diff from previous batch 8.6560 seconds
# Epoch 4/10 | Batch 70 | Time diff from previous batch 8.6443 seconds
# Epoch 4/10 | Batch 71 | Time diff from previous batch 8.6261 seconds
# Epoch 4/10 | Batch 72 | Time diff from previous batch 8.6129 seconds
# Epoch 4/10 | Batch 73 | Time diff from previous batch 8.5561 seconds
# Epoch 4/10 | Batch 74 | Time diff from previous batch 8.5899 seconds
# Epoch 4/10 | Batch 75 | Time diff from previous batch 8.6251 seconds
# Epoch 4/10 | Batch 76 | Time diff from previous batch 8.6534 seconds
# Epoch 4/10 | Batch 77 | Time diff from previous batch 8.6508 seconds
# Epoch 4/10 | Batch 78 | Time diff from previous batch 8.6870 seconds
# Epoch 4/10 | Batch 79 | Time diff from previous batch 8.5929 seconds
# Epoch 4/10 | Batch 80
# Time 137.94164967536926
# Running Training Loss: 1.071
# Running Training Accuracy: 73.44%
# Validation Loss: 0.724
# Validation Accuracy: 81.78%
# Epoch 4/10 | Batch 80 | Time diff from previous batch 138.3417 seconds
# Epoch 4/10 | Batch 81 | Time diff from previous batch 8.6583 seconds
# Epoch 4/10 | Batch 82 | Time diff from previous batch 8.6396 seconds
# Epoch 4/10 | Batch 83 | Time diff from previous batch 8.6011 seconds
# Epoch 4/10 | Batch 84 | Time diff from previous batch 8.6215 seconds
# Epoch 4/10 | Batch 85 | Time diff from previous batch 8.8428 seconds
# Epoch 4/10 | Batch 86 | Time diff from previous batch 9.0759 seconds
# Epoch 4/10 | Batch 87 | Time diff from previous batch 8.8874 seconds
# Epoch 4/10 | Batch 88 | Time diff from previous batch 9.0463 seconds
# Epoch 4/10 | Batch 89 | Time diff from previous batch 9.1966 seconds
# Epoch 4/10 | Batch 90 | Time diff from previous batch 9.1829 seconds
# Epoch 4/10 | Batch 91 | Time diff from previous batch 8.9784 seconds
# Epoch 4/10 | Batch 92 | Time diff from previous batch 9.0122 seconds
# Epoch 4/10 | Batch 93 | Time diff from previous batch 9.0946 seconds
# Epoch 4/10 | Batch 94 | Time diff from previous batch 8.8033 seconds
# Epoch 4/10 | Batch 95 | Time diff from previous batch 8.7975 seconds
# Epoch 4/10 | Batch 96 | Time diff from previous batch 8.7975 seconds
# Epoch 4/10 | Batch 97 | Time diff from previous batch 8.7677 seconds
# Epoch 4/10 | Batch 98 | Time diff from previous batch 8.7033 seconds
# Epoch 4/10 | Batch 99 | Time diff from previous batch 8.7583 seconds
# Epoch 4/10 | Batch 100
# Time 140.11180806159973
# Running Training Loss: 1.122
# Running Training Accuracy: 71.09%
# Validation Loss: 0.723
# Validation Accuracy: 83.08%
# Epoch 4/10 | Batch 100 | Time diff from previous batch 140.6285 seconds
# Epoch 4/10 | Batch 101 | Time diff from previous batch 8.7969 seconds
# Epoch 4/10 | Batch 102 | Time diff from previous batch 8.4688 seconds
# Epoch 5/10 | Batch 0 | Time diff from previous batch 5.7365 seconds
# Epoch 5/10 | Batch 1 | Time diff from previous batch 8.8496 seconds
# Epoch 5/10 | Batch 2 | Time diff from previous batch 8.8393 seconds
# Epoch 5/10 | Batch 3 | Time diff from previous batch 8.9953 seconds
# Epoch 5/10 | Batch 4 | Time diff from previous batch 8.8484 seconds
# Epoch 5/10 | Batch 5 | Time diff from previous batch 8.8588 seconds
# Epoch 5/10 | Batch 6 | Time diff from previous batch 8.9696 seconds
# Epoch 5/10 | Batch 7 | Time diff from previous batch 8.9079 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 41
#      39 ps = torch.exp(log_ps)
#      40 top_ps, top_class = ps.topk(1,dim=1)
# ---> 41 matches = (top_class == labels.view(*top_class.shape)).type(torch.FloatTensor)
#      42 accuracy = matches.mean()
#      44 # resets optimiser gradient and tracks metrics
#
# KeyboardInterrupt:

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
#### Do validation on the test set

# defines test accuracy
test_accuracy = 0

# defines start time
start_time = time.time()
print('Validation started.')

# defines tests
for images,labels in testloader:
    model.eval()
    images,labels = images.to(device),labels.to(device)
    log_ps = model.forward(images)
    ps = torch.exp(log_ps)
    top_ps,top_class = ps.topk(1,dim=1)
    matches = (top_class == labels.view(*top_class.shape)).type(torch.FloatTensor)
    accuracy = matches.mean()
    test_accuracy += accuracy

# defines end time
end_time = time.time()
print('Validation ended.')
validation_time = end_time - start_time
print('Validation time: {:.0f}m {:.0f}s'.format(validation_time / 60, validation_time % 60))
    
# prints metrics
print(f'Test Accuracy: {test_accuracy/len(testloader)*100:.2f}%')
# Out:
# Epoch 1/10 | Batch 0 | Time 104.80677628517151
# Epoch 1/10 | Batch 1 | Time 12.515891313552856
# Epoch 1/10 | Batch 2 | Time 10.904597520828247
# Epoch 1/10 | Batch 3 | Time 11.000577926635742
# Epoch 2/10 | Batch 85 | Time 10.88045072555542
# Epoch 2/10 | Batch 86 | Time 10.88433027267456
# Epoch 2/10 | Batch 87 | Time 11.199951171875
# Epoch 2/10 | Batch 88 | Time 11.037434816360474
# Epoch 2/10 | Batch 89 | Time 10.830525159835815
# Epoch 2/10 | Batch 90 | Time 10.790482997894287
# Epoch 2/10 | Batch 91 | Time 10.856382369995117
# Epoch 2/10 | Batch 92 | Time 10.813179731369019
# Epoch 2/10 | Batch 93 | Time 10.763501167297363
# Epoch 2/10 | Batch 94 | Time 10.869751453399658
# Epoch 2/10 | Batch 95 | Time 10.833745002746582
# Epoch 2/10 | Batch 96 | Time 10.889360666275024
# Epoch 2/10 | Batch 97 | Time 10.936407089233398
# Epoch 2/10 | Batch 98 | Time 10.936585187911987
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 39
#      37 ps = torch.exp(log_ps)
#      38 top_ps, top_class = ps.topk(1,dim=1)
# ---> 39 matches = (top_class == labels.view(*top_class.shape)).type(torch.FloatTensor)
#      40 accuracy = matches.mean()
#      42 # resets optimiser gradient and tracks metrics
#
# KeyboardInterrupt:

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# Save the checkpoint 
    
# saves the checkpoint in the current directory
destination_directory = None
class_to_idx = train_data.class_to_idx # improves label to name mapping

# saves the model's state_dict
def save_model(trained_model,destination_directory,model_arch,class_to_idx):
    # defines model's checkpoint
    model_checkpoint = {'model_arch':model_arch, 
                    'clf_input':25088,
                    'clf_output':102,
                    'clf_hidden':4096,
                    'state_dict':trained_model.state_dict(),
                    'model_class_to_index':class_to_idx,
                    }
    
    # saves model in current directory
    if destination_directory:
        torch.save(model_checkpoint,destination_directory+"/"+model_arch+"_checkpoint.pth")
        print(f"{model_arch} successfully saved to {destination_directory}")
    else:
        torch.save(model_checkpoint,model_arch+"_checkpoint.pth")
        print(f"{model_arch} successfully saved to current directory as {model_arch}_checkpoint.pth")

# calls save_model
save_model(model,destination_directory,'vgg16',class_to_idx)
# Out:
# Our model:
#
#  Classifier(
#   (fc1): Linear(in_features=150528, out_features=7168, bias=True)
#   (fc2): Linear(in_features=7168, out_features=1024, bias=True)
#   (fc3): Linear(in_features=1024, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=102, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )
#
# The state dict keys:
#
#  odict_keys(['fc1.weight', 'fc1.bias', 'fc2.weight', 'fc2.bias', 'fc3.weight', 'fc3.bias', 'fc4.weight', 'fc4.bias'])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 5
#       2 print("Our model: \n\n", model, '\n')
#       3 print("The state dict keys: \n\n", model.state_dict().keys())
# ----> 5 torch.save(model.state_dict(), 'checkpoint.pth')
#
# File ~\anaconda3\Lib\site-packages\torch\serialization.py:850, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     848 if _use_new_zipfile_serialization:
#     849     with _open_zipfile_writer(f) as opened_zipfile:
# --> 850         _save(
#     851             obj,
#     852             opened_zipfile,
#     853             pickle_module,
#     854             pickle_protocol,
#     855             _disable_byteorder_record,
#     856         )
#     857         return
#     858 else:
#
# File ~\anaconda3\Lib\site-packages\torch\serialization.py:1114, in _save(obj, zip_file, pickle_module, pickle_protocol, _disable_byteorder_record)
#    1112     storage = storage.cpu()
#    1113 # Now that it is on the CPU we can directly copy it into the zip file
# -> 1114 zip_file.write_record(name, storage, num_bytes)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# Write a function that loads a checkpoint and rebuilds the model

checkpoint = 'vgg16_checkpoint.pth'

# function that accepts two arguments: filepath (location of checkpoint) and device(gpu/cpu)
def load_checkpoint(filepath,device):
    # loads the GPU when available
    if device=="gpu":
        map_location=lambda device, loc: device.cuda()
    else:
        map_location='cpu'
    # redefines checkpoint
    checkpoint = torch.load(f=filepath,map_location=map_location)

    # function returns number of input units, output units, hidden units, and state_dict
    return checkpoint['model_arch'],checkpoint['clf_input'], checkpoint['clf_output'], checkpoint['clf_hidden'],checkpoint['state_dict'],checkpoint['model_class_to_index']

# loads the checkpoint
model_arch,input_units, output_units, hidden_units, state_dict, class_to_idx = load_checkpoint(checkpoint,device)
model.load_state_dict(state_dict)

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
# Process a PIL image for use in a PyTorch model
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    print(type(image))
    image = image.resize((256, 256))
    width, height = image.size   # Get dimensions

    left = (width - 224)//2
    top = (height - 224)//2
    right = (width + 224)//2
    bottom = (height + 224)//2

    image = image.crop((left, top, right, bottom))
    np_image = np.array(image)
    
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    
    np_image = (np_image - mean) / std
    return np_image.transpose((2, 0, 1))

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
# Implement the code to predict the class from an image file
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    model.eval()
    image = Image.open(image_path)
    image = process_image(image)
    t = torch.from_numpy(image).type(torch.FloatTensor).unsqueeze(0).to(device)
    imshow(t.cpu())
    output = model.forward(t)
    probs = torch.exp(output)
    print(probs)
    probs, classes = probs.topk(topk)
    
    return probs, classes

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
image_path = "flowers/test/37/image_06739.jpg"

# Set up plot
plt.figure(figsize = (6,10))
ax = plt.subplot(2,1,1)

# Set up title
flower_num = image_path.split('/')[2]
title_ = cat_to_name[flower_num]

# Plot flower
img = process_image(image_path)
imshow(img, ax, title = title_);

# Make prediction
probs, labs, flowers = predict(image_path, model) 

# Plot bar chart
plt.subplot(2,1,2)
sns.barplot(x=probs, y=flowers, color=sns.color_palette()[0]);
plt.show()

# %%
## Do validation on the test set

criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=0.003)

model.to(device)

epochs = 8
steps = 0

train_losses, test_losses = [], []
for e in range(epochs):
    print("Epoch: {}/{}".format(e+1, epochs))
    running_loss = 0
    
    batch_idx = 0
    for images, labels in train_loader:
        batch_idx += 1
        images, labels = images.to(device), labels.to(device)
        print("Batch index: {}".format(batch_idx))
        
        optimizer.zero_grad()
        log_ps = model(images)
        loss = criterion(log_ps, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        print("Batch running loss: {}".format(loss.item()))
        
    else:
        ## Implement the validation pass and print out the validation accuracy
        tot_test_loss = 0
        test_correct = 0  # Number of correct predictions on the test set
        
        # Turn off gradients for validation, saves memory and computations
        with torch.no_grad():
            # set model to evaluation mode
            model.eval()
            
            for images, labels in test_loader:
                images, labels = images.to(device), labels.to(device)
                log_ps = model(images)
                loss = criterion(log_ps, labels)
                tot_test_loss += loss.item()

                ps = torch.exp(log_ps)
                top_p, top_class = ps.topk(1, dim=1)
                equals = top_class == labels.view(*top_class.shape)
                test_correct += equals.sum().item()

        # Get mean loss to enable comparison between train and test sets
        train_loss = running_loss / len(train_loader.dataset)
        test_loss = tot_test_loss / len(test_loader.dataset)

        # At completion of epoch
        train_losses.append(train_loss)
        test_losses.append(test_loss)
        
        # set model back to train mode
        model.train()

        print("Epoch: {}/{}.. ".format(e+1, epochs),
              "Training Loss: {:.3f}.. ".format(train_loss),
              "Test Loss: {:.3f}.. ".format(test_loss),
              "Test Accuracy: {:.3f}".format(test_correct / len(test_loader.dataset)))

# %%
## Do validation on the test set
# SOLUTION ADAPTED FROM https://github.com/nouran551/Udacity-Image-Classifier/blob/master/Image%20Classifier.ipynb

criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)

model.to(device) # device = cuda @ beginning of the notebook
print(device)

epochs = 10 # 10 epochs seem reasonable for our purpose
#steps = 0

#train_losses, test_losses = [], []
for e in range(epochs):
    print("Epoch: {}/{}".format(e+1, epochs))
    
    # Set to training mode
    model.train()
     
    # Loss and Accuracy within the epoch
    train_loss = 0.0
    train_acc = 0.0
     
    valid_loss = 0.0
    valid_acc = 0.0
 
    for i, (inputs, labels) in enumerate(train_loader):
 
        inputs = inputs.to(device)
        labels = labels.to(device)
         
        # Clean existing gradients
        optimizer.zero_grad()
         
        outputs = model(inputs) # Forward pass - compute outputs on input data using the model
        loss = criterion(outputs, labels) # Compute loss
        loss.backward() # Backpropagate the gradients
        optimizer.step() # Update the parameters
         
        # Compute the total loss for the batch and add it to train_loss
        train_loss += loss.item() * inputs.size(0)
         
        # Compute the accuracy
        ret, predictions = torch.max(outputs.data, 1)
        correct_counts = predictions.eq(labels.data.view_as(predictions))
         
        acc = torch.mean(correct_counts.type(torch.FloatTensor)) # Compute the mean using float type
         
        train_acc += acc.item() * inputs.size(0) # Compute total accuracy of the batch and add it to train_acc
         
        # Visualization purpose
        print("Batch no: {:03d}, Loss on trainig: {:.5f}, Accuracy: {:.5f}".format(i, loss.item(), acc.item()))
