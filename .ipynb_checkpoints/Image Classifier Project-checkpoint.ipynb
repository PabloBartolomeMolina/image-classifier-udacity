# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Check torch version and CUDA status if GPU is enabled.
import torch
print(torch.__version__)
print(torch.cuda.is_available()) # Should return True when GPU is enabled. 

# Imports here
import numpy as np
import matplotlib.pyplot as plt

from torch import nn, tensor, optim
import torch.nn.functional as F
from torch.autograd import Variable
from torchvision import datasets, transforms
import torchvision.models as models

import seaborn as sns
import time
import PIL
from PIL import Image

device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 2.5.1
# True
# 'cuda'

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

print(data_dir)
print(train_dir)
print(valid_dir)
print(test_dir)
# Out:
# flowers
# flowers/train
# flowers/valid
# flowers/test

# %%
# Define your transforms for the training, validation, and testing sets

# For normalization, values of mean and of standard deviation correspond to those found online as recommended when working
# with PyTorch.
# See https://pytorch.org/vision/0.8/models.html
data_transforms = { 
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],
                             [0.229,0.224,0.225])
    ]),
    'valid': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],
                             [0.229,0.224,0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],
                             [0.229,0.224,0.225])
    ])
}

# Load the datasets with ImageFolder
image_datasets = {
    'train': datasets.ImageFolder(train_dir, transform=data_transforms['train']),
    'valid': datasets.ImageFolder(valid_dir, transform=data_transforms['valid']),
    'test': datasets.ImageFolder(test_dir, transform=data_transforms['test'])
}

# Using the image datasets and the trainforms, define the dataloaders
train_loader = torch.utils.data.DataLoader(image_datasets['train'], batch_size=64, shuffle=True)
validation_loader = torch.utils.data.DataLoader(image_datasets['valid'], batch_size =32)
test_loader = torch.utils.data.DataLoader(image_datasets['test'], batch_size = 32)
#validation_loader = torch.utils.data.DataLoader(image_datasets['valid'], batch_size =64,shuffle = True)
#test_loader = torch.utils.data.DataLoader(image_datasets['test'], batch_size = 64, shuffle = True)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)
    # prints json file
    #print(cat_to_name)
    
no_output_categories = len(cat_to_name)
print("Categories: {}".format(no_output_categories))
# Out:
# Categories: 102

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# Build and train your network

model = models.vgg16(pretrained=True)

for param in model.parameters():
    param.requires_grad = False
    
from collections import OrderedDict

classifier_layers = OrderedDict({
    'fc1' : nn.Linear(25088, 4096),
    'relu1': nn.ReLU(),
    'dropout1': nn.Dropout(0.05),
    'fc2' : nn.Linear(4096, 102),
    'softmax': nn.LogSoftmax(dim=1)
})
    
classifier = nn.Sequential(classifier_layers)

model.classifier = classifier
model.to(device)
# Out:
# C:\Users\pablo\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\pablo\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=4096, bias=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.05, inplace=False)
#     (fc2): Linear(in_features=4096, out_features=102, bias=True)
#     (softmax): LogSoftmax(dim=1)
#   )
# )

# %%
# sets the training hyperparameters

# Before reaching end of 1st epoch during training when configured for 10 epohcs, validation accuracy >70%.
# At the end of the 3rd epoch, validation accuracy ~77%.
# At the end of the 3rd epoch, validation accuracy ~83%.
# With 10 epohcs, we go up to 83.4% of accuracy, which does not seem a lot of gain in 7 epochs for the needed training time.
# Increment in  validation accuracy is small for each epoch, so 10 are not really needed.
epochs = 10 # Should be good enough to avoid overfitting
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=0.003)

steps = 0

print_every = 20 # the model trains on 20 batches of images at a time

running_loss = running_accuracy = 0
validation_losses, training_losses = [],[]

start = time.time() # Time used as reference to see the time cost of training the model.

for e in range(epochs):
    batches = 0 # 1 batch = 64 images

    model.train() # Training phase.

    for images,labels in train_loader:
        # Print out partial metrics and time to see progress and bottlenecks.
        if (batches == 0) and (e == 0):
            print(f'Epoch {e+1}/{epochs} | Batch {batches} | Time diff from previous batch {0.0:.4f} seconds')
        else:
            print(f'Epoch {e+1}/{epochs} | Batch {batches} | Time diff from previous batch {time.time() - start:.4f} seconds')
        start = time.time() # defines start time
        batches += 1

        images,labels = images.to(device),labels.to(device)

        # Pushes batch through network forward and then get the gradient backwards to update the weights.
        log_ps = model.forward(images)
        loss = criterion(log_ps,labels)
        loss.backward()
        optimizer.step()

        # Calculates the metrics.
        ps = torch.exp(log_ps)
        top_ps, top_class = ps.topk(1,dim=1)
        matches = (top_class == labels.view(*top_class.shape)).type(torch.FloatTensor)
        accuracy = matches.mean()

        # Resets optimiser gradient and tracks metrics.
        optimizer.zero_grad()
        running_loss += loss.item()
        running_accuracy += accuracy.item()

        # runs the model on the validation set every 5 loops
        if batches%print_every == 0:
            end = time.time()
            training_time = end-start
            start = time.time()

            # Resets the metrics
            validation_loss = 0
            validation_accuracy = 0

            model.eval()  # Evaluation phase.
            with torch.no_grad(): # Save memory - turns off calculation of gradients.
                for images,labels in validation_loader:
                    images,labels = images.to(device),labels.to(device)
                    log_ps = model.forward(images)
                    loss = criterion(log_ps,labels)
                    ps = torch.exp(log_ps)
                    top_ps, top_class = ps.topk(1,dim=1)
                    matches = (top_class == labels.view(*top_class.shape)).type(torch.FloatTensor)
                    accuracy = matches.mean()

                    # Update validation metrics (used to see progress of the model every 20 steps).
                    validation_loss += loss.item()
                    validation_accuracy += accuracy.item()
                
            # Update training metrics.
            end = time.time()
            validation_time = end-start
            validation_losses.append(running_loss/print_every)
            training_losses.append(validation_loss/len(validation_loader))
                
            # Prints out metrics to track the progress.
            print(f'Epoch {e+1}/{epochs} | Batch {batches}')
            print(f'Time {validation_time}')
            print(f'Running Training Loss: {running_loss/print_every:.3f}')
            print(f'Running Training Accuracy: {running_accuracy/print_every*100:.2f}%')
            print(f'Validation Loss: {validation_loss/len(validation_loader):.3f}')
            print(f'Validation Accuracy: {validation_accuracy/len(validation_loader)*100:.2f}%')

            # Resets the metrics.
            running_loss = running_accuracy = 0
            model.train()  # Training phase.
# Out:
# Epoch 1/10 | Batch 0 | Time diff from previous batch 0.0000 seconds
# Epoch 1/10 | Batch 1 | Time diff from previous batch 3.5452 seconds
# Epoch 1/10 | Batch 2 | Time diff from previous batch 10.3310 seconds
# Epoch 1/10 | Batch 3 | Time diff from previous batch 7.7296 seconds
# Epoch 1/10 | Batch 4 | Time diff from previous batch 7.6959 seconds
# Epoch 1/10 | Batch 5 | Time diff from previous batch 7.7308 seconds
# Epoch 1/10 | Batch 6 | Time diff from previous batch 7.8952 seconds
# Epoch 1/10 | Batch 7 | Time diff from previous batch 7.9881 seconds
# Epoch 1/10 | Batch 8 | Time diff from previous batch 7.6784 seconds
# Epoch 1/10 | Batch 9 | Time diff from previous batch 7.7603 seconds
# Epoch 1/10 | Batch 10 | Time diff from previous batch 8.0964 seconds
# Epoch 1/10 | Batch 11 | Time diff from previous batch 7.9577 seconds
# Epoch 1/10 | Batch 12 | Time diff from previous batch 7.6962 seconds
# Epoch 1/10 | Batch 13 | Time diff from previous batch 7.6761 seconds
# Epoch 1/10 | Batch 14 | Time diff from previous batch 7.7463 seconds
# Epoch 1/10 | Batch 15 | Time diff from previous batch 7.6822 seconds
# Epoch 1/10 | Batch 16 | Time diff from previous batch 7.6598 seconds
# Epoch 1/10 | Batch 17 | Time diff from previous batch 7.6688 seconds
# Epoch 1/10 | Batch 18 | Time diff from previous batch 8.0145 seconds
# Epoch 1/10 | Batch 19 | Time diff from previous batch 7.7094 seconds
# Epoch 1/10 | Batch 20
# Time 56.728844165802
# Running Training Loss: 13.900
# Running Training Accuracy: 9.30%
# Validation Loss: 3.311
# Validation Accuracy: 28.29%
# Epoch 1/10 | Batch 20 | Time diff from previous batch 57.2452 seconds
# Epoch 1/10 | Batch 21 | Time diff from previous batch 7.8137 seconds
# Epoch 1/10 | Batch 22 | Time diff from previous batch 7.6807 seconds
# Epoch 1/10 | Batch 23 | Time diff from previous batch 7.8421 seconds
# Epoch 1/10 | Batch 24 | Time diff from previous batch 7.8243 seconds
# Epoch 1/10 | Batch 25 | Time diff from previous batch 7.8806 seconds
# Epoch 1/10 | Batch 26 | Time diff from previous batch 7.8033 seconds
# Epoch 1/10 | Batch 27 | Time diff from previous batch 7.6874 seconds
# Epoch 1/10 | Batch 28 | Time diff from previous batch 7.6984 seconds
# Epoch 1/10 | Batch 29 | Time diff from previous batch 7.7466 seconds
# Epoch 1/10 | Batch 30 | Time diff from previous batch 7.6771 seconds
# Epoch 1/10 | Batch 31 | Time diff from previous batch 7.6797 seconds
# Epoch 1/10 | Batch 32 | Time diff from previous batch 7.7537 seconds
# Epoch 1/10 | Batch 33 | Time diff from previous batch 7.7751 seconds
# Epoch 1/10 | Batch 34 | Time diff from previous batch 7.6809 seconds
# Epoch 1/10 | Batch 35 | Time diff from previous batch 7.6690 seconds
# Epoch 1/10 | Batch 36 | Time diff from previous batch 7.7136 seconds
# Epoch 1/10 | Batch 37 | Time diff from previous batch 7.7529 seconds
# Epoch 1/10 | Batch 38 | Time diff from previous batch 7.6522 seconds
# Epoch 1/10 | Batch 39 | Time diff from previous batch 7.8683 seconds
# Epoch 1/10 | Batch 40
# Time 55.91345763206482
# Running Training Loss: 2.920
# Running Training Accuracy: 34.77%
# Validation Loss: 1.901
# Validation Accuracy: 51.59%
# Epoch 1/10 | Batch 40 | Time diff from previous batch 56.4311 seconds
# Epoch 1/10 | Batch 41 | Time diff from previous batch 7.6709 seconds
# Epoch 1/10 | Batch 42 | Time diff from previous batch 7.6598 seconds
# Epoch 1/10 | Batch 43 | Time diff from previous batch 7.6565 seconds
# Epoch 1/10 | Batch 44 | Time diff from previous batch 7.8415 seconds
# Epoch 1/10 | Batch 45 | Time diff from previous batch 7.7144 seconds
# Epoch 1/10 | Batch 46 | Time diff from previous batch 7.6702 seconds
# Epoch 1/10 | Batch 47 | Time diff from previous batch 7.7182 seconds
# Epoch 1/10 | Batch 48 | Time diff from previous batch 7.6705 seconds
# Epoch 1/10 | Batch 49 | Time diff from previous batch 7.7295 seconds
# Epoch 1/10 | Batch 50 | Time diff from previous batch 7.6759 seconds
# Epoch 1/10 | Batch 51 | Time diff from previous batch 7.6495 seconds
# Epoch 1/10 | Batch 52 | Time diff from previous batch 7.7985 seconds
# Epoch 1/10 | Batch 53 | Time diff from previous batch 7.7378 seconds
# Epoch 1/10 | Batch 54 | Time diff from previous batch 7.6706 seconds
# Epoch 1/10 | Batch 55 | Time diff from previous batch 7.6700 seconds
# Epoch 1/10 | Batch 56 | Time diff from previous batch 7.6911 seconds
# Epoch 1/10 | Batch 57 | Time diff from previous batch 7.6486 seconds
# Epoch 1/10 | Batch 58 | Time diff from previous batch 7.6711 seconds
# Epoch 1/10 | Batch 59 | Time diff from previous batch 8.1414 seconds
# Epoch 1/10 | Batch 60
# Time 55.06572151184082
# Running Training Loss: 2.166
# Running Training Accuracy: 44.84%
# Validation Loss: 1.529
# Validation Accuracy: 58.99%
# Epoch 1/10 | Batch 60 | Time diff from previous batch 55.5429 seconds
# Epoch 1/10 | Batch 61 | Time diff from previous batch 7.8883 seconds
# Epoch 1/10 | Batch 62 | Time diff from previous batch 7.6880 seconds
# Epoch 1/10 | Batch 63 | Time diff from previous batch 7.6398 seconds
# Epoch 1/10 | Batch 64 | Time diff from previous batch 7.7603 seconds
# Epoch 1/10 | Batch 65 | Time diff from previous batch 7.7099 seconds
# Epoch 1/10 | Batch 66 | Time diff from previous batch 7.6972 seconds
# Epoch 1/10 | Batch 67 | Time diff from previous batch 7.6583 seconds
# Epoch 1/10 | Batch 68 | Time diff from previous batch 7.8400 seconds
# Epoch 1/10 | Batch 69 | Time diff from previous batch 7.6923 seconds
# Epoch 1/10 | Batch 70 | Time diff from previous batch 7.6821 seconds
# Epoch 1/10 | Batch 71 | Time diff from previous batch 7.6645 seconds
# Epoch 1/10 | Batch 72 | Time diff from previous batch 7.7036 seconds
# Epoch 1/10 | Batch 73 | Time diff from previous batch 7.7371 seconds
# Epoch 1/10 | Batch 74 | Time diff from previous batch 7.6611 seconds
# Epoch 1/10 | Batch 75 | Time diff from previous batch 7.6992 seconds
# Epoch 1/10 | Batch 76 | Time diff from previous batch 7.6698 seconds
# Epoch 1/10 | Batch 77 | Time diff from previous batch 7.7224 seconds
# Epoch 1/10 | Batch 78 | Time diff from previous batch 7.6700 seconds
# Epoch 1/10 | Batch 79 | Time diff from previous batch 7.8982 seconds
# Epoch 1/10 | Batch 80
# Time 56.434629917144775
# Running Training Loss: 1.911
# Running Training Accuracy: 52.27%
# Validation Loss: 1.291
# Validation Accuracy: 67.05%
# Epoch 1/10 | Batch 80 | Time diff from previous batch 56.9440 seconds
# Epoch 1/10 | Batch 81 | Time diff from previous batch 7.7176 seconds
# Epoch 1/10 | Batch 82 | Time diff from previous batch 7.6679 seconds
# Epoch 1/10 | Batch 83 | Time diff from previous batch 7.6572 seconds
# Epoch 1/10 | Batch 84 | Time diff from previous batch 7.6700 seconds
# Epoch 1/10 | Batch 85 | Time diff from previous batch 7.7269 seconds
# Epoch 1/10 | Batch 86 | Time diff from previous batch 7.6897 seconds
# Epoch 1/10 | Batch 87 | Time diff from previous batch 7.6730 seconds
# Epoch 1/10 | Batch 88 | Time diff from previous batch 7.7282 seconds
# Epoch 1/10 | Batch 89 | Time diff from previous batch 7.6716 seconds
# Epoch 1/10 | Batch 90 | Time diff from previous batch 7.7066 seconds
# Epoch 1/10 | Batch 91 | Time diff from previous batch 7.6634 seconds
# Epoch 1/10 | Batch 92 | Time diff from previous batch 7.7977 seconds
# Epoch 1/10 | Batch 93 | Time diff from previous batch 7.6336 seconds
# Epoch 1/10 | Batch 94 | Time diff from previous batch 7.6615 seconds
# Epoch 1/10 | Batch 95 | Time diff from previous batch 7.6806 seconds
# Epoch 1/10 | Batch 96 | Time diff from previous batch 7.7553 seconds
# Epoch 1/10 | Batch 97 | Time diff from previous batch 7.6697 seconds
# Epoch 1/10 | Batch 98 | Time diff from previous batch 7.6510 seconds
# Epoch 1/10 | Batch 99 | Time diff from previous batch 7.6958 seconds
# Epoch 1/10 | Batch 100
# Time 55.90993809700012
# Running Training Loss: 1.675
# Running Training Accuracy: 56.72%
# Validation Loss: 1.072
# Validation Accuracy: 70.51%
# Epoch 1/10 | Batch 100 | Time diff from previous batch 56.5032 seconds
# Epoch 1/10 | Batch 101 | Time diff from previous batch 7.6988 seconds
# Epoch 1/10 | Batch 102 | Time diff from previous batch 7.3584 seconds
# Epoch 2/10 | Batch 0 | Time diff from previous batch 1.8974 seconds
# Epoch 2/10 | Batch 1 | Time diff from previous batch 7.6342 seconds
# Epoch 2/10 | Batch 2 | Time diff from previous batch 7.7502 seconds
# Epoch 2/10 | Batch 3 | Time diff from previous batch 7.7312 seconds
# Epoch 2/10 | Batch 4 | Time diff from previous batch 7.6411 seconds
# Epoch 2/10 | Batch 5 | Time diff from previous batch 7.6445 seconds
# Epoch 2/10 | Batch 6 | Time diff from previous batch 7.6565 seconds
# Epoch 2/10 | Batch 7 | Time diff from previous batch 7.6812 seconds
# Epoch 2/10 | Batch 8 | Time diff from previous batch 7.6559 seconds
# Epoch 2/10 | Batch 9 | Time diff from previous batch 7.6546 seconds
# Epoch 2/10 | Batch 10 | Time diff from previous batch 7.7197 seconds
# Epoch 2/10 | Batch 11 | Time diff from previous batch 7.6415 seconds
# Epoch 2/10 | Batch 12 | Time diff from previous batch 7.6508 seconds
# Epoch 2/10 | Batch 13 | Time diff from previous batch 7.6618 seconds
# Epoch 2/10 | Batch 14 | Time diff from previous batch 7.7163 seconds
# Epoch 2/10 | Batch 15 | Time diff from previous batch 7.6614 seconds
# Epoch 2/10 | Batch 16 | Time diff from previous batch 7.6148 seconds
# Epoch 2/10 | Batch 17 | Time diff from previous batch 7.6472 seconds
# Epoch 2/10 | Batch 18 | Time diff from previous batch 7.6855 seconds
# Epoch 2/10 | Batch 19 | Time diff from previous batch 7.6092 seconds
# Epoch 2/10 | Batch 20
# Time 55.236337184906006
# Running Training Loss: 1.779
# Running Training Accuracy: 69.92%
# Validation Loss: 1.051
# Validation Accuracy: 70.05%
# Epoch 2/10 | Batch 20 | Time diff from previous batch 55.6947 seconds
# Epoch 2/10 | Batch 21 | Time diff from previous batch 7.6361 seconds
# Epoch 2/10 | Batch 22 | Time diff from previous batch 7.8509 seconds
# Epoch 2/10 | Batch 23 | Time diff from previous batch 7.9203 seconds
# Epoch 2/10 | Batch 24 | Time diff from previous batch 7.7880 seconds
# Epoch 2/10 | Batch 25 | Time diff from previous batch 7.8664 seconds
# Epoch 2/10 | Batch 26 | Time diff from previous batch 7.6430 seconds
# Epoch 2/10 | Batch 27 | Time diff from previous batch 7.6514 seconds
# Epoch 2/10 | Batch 28 | Time diff from previous batch 7.6207 seconds
# Epoch 2/10 | Batch 29 | Time diff from previous batch 7.6924 seconds
# Epoch 2/10 | Batch 30 | Time diff from previous batch 7.6403 seconds
# Epoch 2/10 | Batch 31 | Time diff from previous batch 7.6519 seconds
# Epoch 2/10 | Batch 32 | Time diff from previous batch 7.6399 seconds
# Epoch 2/10 | Batch 33 | Time diff from previous batch 7.8135 seconds
# Epoch 2/10 | Batch 34 | Time diff from previous batch 7.6967 seconds
# Epoch 2/10 | Batch 35 | Time diff from previous batch 7.6478 seconds
# Epoch 2/10 | Batch 36 | Time diff from previous batch 7.6473 seconds
# Epoch 2/10 | Batch 37 | Time diff from previous batch 7.6498 seconds
# Epoch 2/10 | Batch 38 | Time diff from previous batch 7.7065 seconds
# Epoch 2/10 | Batch 39 | Time diff from previous batch 7.6581 seconds
# Epoch 2/10 | Batch 40
# Time 55.4044828414917
# Running Training Loss: 1.484
# Running Training Accuracy: 61.88%
# Validation Loss: 1.000
# Validation Accuracy: 73.49%
# Epoch 2/10 | Batch 40 | Time diff from previous batch 55.9041 seconds
# Epoch 2/10 | Batch 41 | Time diff from previous batch 7.6200 seconds
# Epoch 2/10 | Batch 42 | Time diff from previous batch 7.7693 seconds
# Epoch 2/10 | Batch 43 | Time diff from previous batch 7.6692 seconds
# Epoch 2/10 | Batch 44 | Time diff from previous batch 7.6159 seconds
# Epoch 2/10 | Batch 45 | Time diff from previous batch 7.6590 seconds
# Epoch 2/10 | Batch 46 | Time diff from previous batch 7.7184 seconds
# Epoch 2/10 | Batch 47 | Time diff from previous batch 7.6342 seconds
# Epoch 2/10 | Batch 48 | Time diff from previous batch 7.6415 seconds
# Epoch 2/10 | Batch 49 | Time diff from previous batch 7.6397 seconds
# Epoch 2/10 | Batch 50 | Time diff from previous batch 7.9044 seconds
# Epoch 2/10 | Batch 51 | Time diff from previous batch 7.8520 seconds
# Epoch 2/10 | Batch 52 | Time diff from previous batch 7.9024 seconds
# Epoch 2/10 | Batch 53 | Time diff from previous batch 7.6725 seconds
# Epoch 2/10 | Batch 54 | Time diff from previous batch 7.6390 seconds
# Epoch 2/10 | Batch 55 | Time diff from previous batch 7.6366 seconds
# Epoch 2/10 | Batch 56 | Time diff from previous batch 7.6755 seconds
# Epoch 2/10 | Batch 57 | Time diff from previous batch 7.6372 seconds
# Epoch 2/10 | Batch 58 | Time diff from previous batch 7.6922 seconds
# Epoch 2/10 | Batch 59 | Time diff from previous batch 7.6534 seconds
# Epoch 2/10 | Batch 60
# Time 54.055912017822266
# Running Training Loss: 1.480
# Running Training Accuracy: 61.41%
# Validation Loss: 0.935
# Validation Accuracy: 73.93%
# Epoch 2/10 | Batch 60 | Time diff from previous batch 54.3979 seconds
# Epoch 2/10 | Batch 61 | Time diff from previous batch 7.4542 seconds
# Epoch 2/10 | Batch 62 | Time diff from previous batch 7.5488 seconds
# Epoch 2/10 | Batch 63 | Time diff from previous batch 7.6082 seconds
# Epoch 2/10 | Batch 64 | Time diff from previous batch 7.5226 seconds
# Epoch 2/10 | Batch 65 | Time diff from previous batch 7.6692 seconds
# Epoch 2/10 | Batch 66 | Time diff from previous batch 7.6972 seconds
# Epoch 2/10 | Batch 67 | Time diff from previous batch 7.6279 seconds
# Epoch 2/10 | Batch 68 | Time diff from previous batch 7.5253 seconds
# Epoch 2/10 | Batch 69 | Time diff from previous batch 7.5831 seconds
# Epoch 2/10 | Batch 70 | Time diff from previous batch 7.5941 seconds
# Epoch 2/10 | Batch 71 | Time diff from previous batch 7.6148 seconds
# Epoch 2/10 | Batch 72 | Time diff from previous batch 7.5394 seconds
# Epoch 2/10 | Batch 73 | Time diff from previous batch 7.5621 seconds
# Epoch 2/10 | Batch 74 | Time diff from previous batch 7.5495 seconds
# Epoch 2/10 | Batch 75 | Time diff from previous batch 7.6110 seconds
# Epoch 2/10 | Batch 76 | Time diff from previous batch 7.8317 seconds
# Epoch 2/10 | Batch 77 | Time diff from previous batch 7.5485 seconds
# Epoch 2/10 | Batch 78 | Time diff from previous batch 7.5600 seconds
# Epoch 2/10 | Batch 79 | Time diff from previous batch 7.5762 seconds
# Epoch 2/10 | Batch 80
# Time 54.186392068862915
# Running Training Loss: 1.343
# Running Training Accuracy: 66.48%
# Validation Loss: 0.893
# Validation Accuracy: 74.33%
# Epoch 2/10 | Batch 80 | Time diff from previous batch 54.6249 seconds
# Epoch 2/10 | Batch 81 | Time diff from previous batch 7.5139 seconds
# Epoch 2/10 | Batch 82 | Time diff from previous batch 7.5231 seconds
# Epoch 2/10 | Batch 83 | Time diff from previous batch 7.6011 seconds
# Epoch 2/10 | Batch 84 | Time diff from previous batch 7.5771 seconds
# Epoch 2/10 | Batch 85 | Time diff from previous batch 7.5217 seconds
# Epoch 2/10 | Batch 86 | Time diff from previous batch 7.5643 seconds
# Epoch 2/10 | Batch 87 | Time diff from previous batch 7.5416 seconds
# Epoch 2/10 | Batch 88 | Time diff from previous batch 7.5288 seconds
# Epoch 2/10 | Batch 89 | Time diff from previous batch 7.5019 seconds
# Epoch 2/10 | Batch 90 | Time diff from previous batch 7.5044 seconds
# Epoch 2/10 | Batch 91 | Time diff from previous batch 7.7112 seconds
# Epoch 2/10 | Batch 92 | Time diff from previous batch 7.5189 seconds
# Epoch 2/10 | Batch 93 | Time diff from previous batch 7.5239 seconds
# Epoch 2/10 | Batch 94 | Time diff from previous batch 7.5091 seconds
# Epoch 2/10 | Batch 95 | Time diff from previous batch 7.5731 seconds
# Epoch 2/10 | Batch 96 | Time diff from previous batch 7.5228 seconds
# Epoch 2/10 | Batch 97 | Time diff from previous batch 7.5263 seconds
# Epoch 2/10 | Batch 98 | Time diff from previous batch 7.5789 seconds
# Epoch 2/10 | Batch 99 | Time diff from previous batch 7.5847 seconds
# Epoch 2/10 | Batch 100
# Time 51.77491044998169
# Running Training Loss: 1.379
# Running Training Accuracy: 64.77%
# Validation Loss: 0.930
# Validation Accuracy: 75.04%
# Epoch 2/10 | Batch 100 | Time diff from previous batch 52.2258 seconds
# Epoch 2/10 | Batch 101 | Time diff from previous batch 7.5371 seconds
# Epoch 2/10 | Batch 102 | Time diff from previous batch 7.3139 seconds
# Epoch 3/10 | Batch 0 | Time diff from previous batch 1.7648 seconds
# Epoch 3/10 | Batch 1 | Time diff from previous batch 7.5184 seconds
# Epoch 3/10 | Batch 2 | Time diff from previous batch 7.5156 seconds
# Epoch 3/10 | Batch 3 | Time diff from previous batch 7.5035 seconds
# Epoch 3/10 | Batch 4 | Time diff from previous batch 7.4806 seconds
# Epoch 3/10 | Batch 5 | Time diff from previous batch 7.4633 seconds
# Epoch 3/10 | Batch 6 | Time diff from previous batch 7.5434 seconds
# Epoch 3/10 | Batch 7 | Time diff from previous batch 7.4888 seconds
# Epoch 3/10 | Batch 8 | Time diff from previous batch 7.4797 seconds
# Epoch 3/10 | Batch 9 | Time diff from previous batch 7.4823 seconds
# Epoch 3/10 | Batch 10 | Time diff from previous batch 7.7055 seconds
# Epoch 3/10 | Batch 11 | Time diff from previous batch 7.5083 seconds
# Epoch 3/10 | Batch 12 | Time diff from previous batch 7.4824 seconds
# Epoch 3/10 | Batch 13 | Time diff from previous batch 7.4116 seconds
# Epoch 3/10 | Batch 14 | Time diff from previous batch 7.5610 seconds
# Epoch 3/10 | Batch 15 | Time diff from previous batch 7.4416 seconds
# Epoch 3/10 | Batch 16 | Time diff from previous batch 7.4297 seconds
# Epoch 3/10 | Batch 17 | Time diff from previous batch 7.4525 seconds
# Epoch 3/10 | Batch 18 | Time diff from previous batch 7.4405 seconds
# Epoch 3/10 | Batch 19 | Time diff from previous batch 7.4180 seconds
# Epoch 3/10 | Batch 20
# Time 52.01768255233765
# Running Training Loss: 1.437
# Running Training Accuracy: 78.49%
# Validation Loss: 0.935
# Validation Accuracy: 76.74%
# Epoch 3/10 | Batch 20 | Time diff from previous batch 52.3802 seconds
# Epoch 3/10 | Batch 21 | Time diff from previous batch 7.5534 seconds
# Epoch 3/10 | Batch 22 | Time diff from previous batch 7.6104 seconds
# Epoch 3/10 | Batch 23 | Time diff from previous batch 7.5658 seconds
# Epoch 3/10 | Batch 24 | Time diff from previous batch 7.5337 seconds
# Epoch 3/10 | Batch 25 | Time diff from previous batch 7.5683 seconds
# Epoch 3/10 | Batch 26 | Time diff from previous batch 7.4560 seconds
# Epoch 3/10 | Batch 27 | Time diff from previous batch 7.5257 seconds
# Epoch 3/10 | Batch 28 | Time diff from previous batch 7.4818 seconds
# Epoch 3/10 | Batch 29 | Time diff from previous batch 7.4701 seconds
# Epoch 3/10 | Batch 30 | Time diff from previous batch 7.4704 seconds
# Epoch 3/10 | Batch 31 | Time diff from previous batch 7.4818 seconds
# Epoch 3/10 | Batch 32 | Time diff from previous batch 7.5609 seconds
# Epoch 3/10 | Batch 33 | Time diff from previous batch 7.4895 seconds
# Epoch 3/10 | Batch 34 | Time diff from previous batch 7.5888 seconds
# Epoch 3/10 | Batch 35 | Time diff from previous batch 7.5697 seconds
# Epoch 3/10 | Batch 36 | Time diff from previous batch 7.5749 seconds
# Epoch 3/10 | Batch 37 | Time diff from previous batch 7.4741 seconds
# Epoch 3/10 | Batch 38 | Time diff from previous batch 7.5817 seconds
# Epoch 3/10 | Batch 39 | Time diff from previous batch 7.5605 seconds
# Epoch 3/10 | Batch 40
# Time 51.91786527633667
# Running Training Loss: 1.284
# Running Training Accuracy: 67.66%
# Validation Loss: 0.937
# Validation Accuracy: 75.23%
# Epoch 3/10 | Batch 40 | Time diff from previous batch 52.2875 seconds
# Epoch 3/10 | Batch 41 | Time diff from previous batch 7.5789 seconds
# Epoch 3/10 | Batch 42 | Time diff from previous batch 7.4588 seconds
# Epoch 3/10 | Batch 43 | Time diff from previous batch 7.6005 seconds
# Epoch 3/10 | Batch 44 | Time diff from previous batch 7.6358 seconds
# Epoch 3/10 | Batch 45 | Time diff from previous batch 7.6024 seconds
# Epoch 3/10 | Batch 46 | Time diff from previous batch 7.5540 seconds
# Epoch 3/10 | Batch 47 | Time diff from previous batch 7.5465 seconds
# Epoch 3/10 | Batch 48 | Time diff from previous batch 7.5181 seconds
# Epoch 3/10 | Batch 49 | Time diff from previous batch 7.4769 seconds
# Epoch 3/10 | Batch 50 | Time diff from previous batch 7.4523 seconds
# Epoch 3/10 | Batch 51 | Time diff from previous batch 7.4798 seconds
# Epoch 3/10 | Batch 52 | Time diff from previous batch 7.4870 seconds
# Epoch 3/10 | Batch 53 | Time diff from previous batch 7.5883 seconds
# Epoch 3/10 | Batch 54 | Time diff from previous batch 7.4595 seconds
# Epoch 3/10 | Batch 55 | Time diff from previous batch 7.4591 seconds
# Epoch 3/10 | Batch 56 | Time diff from previous batch 7.6297 seconds
# Epoch 3/10 | Batch 57 | Time diff from previous batch 7.5571 seconds
# Epoch 3/10 | Batch 58 | Time diff from previous batch 7.5911 seconds
# Epoch 3/10 | Batch 59 | Time diff from previous batch 7.5608 seconds
# Epoch 3/10 | Batch 60
# Time 52.29417443275452
# Running Training Loss: 1.342
# Running Training Accuracy: 67.81%
# Validation Loss: 0.886
# Validation Accuracy: 77.43%
# Epoch 3/10 | Batch 60 | Time diff from previous batch 52.6596 seconds
# Epoch 3/10 | Batch 61 | Time diff from previous batch 7.5556 seconds
# Epoch 3/10 | Batch 62 | Time diff from previous batch 7.5256 seconds
# Epoch 3/10 | Batch 63 | Time diff from previous batch 7.5842 seconds
# Epoch 3/10 | Batch 64 | Time diff from previous batch 7.5117 seconds
# Epoch 3/10 | Batch 65 | Time diff from previous batch 7.5904 seconds
# Epoch 3/10 | Batch 66 | Time diff from previous batch 7.5878 seconds
# Epoch 3/10 | Batch 67 | Time diff from previous batch 7.5602 seconds
# Epoch 3/10 | Batch 68 | Time diff from previous batch 7.5680 seconds
# Epoch 3/10 | Batch 69 | Time diff from previous batch 7.5591 seconds
# Epoch 3/10 | Batch 70 | Time diff from previous batch 7.4732 seconds
# Epoch 3/10 | Batch 71 | Time diff from previous batch 7.5737 seconds
# Epoch 3/10 | Batch 72 | Time diff from previous batch 7.4622 seconds
# Epoch 3/10 | Batch 73 | Time diff from previous batch 7.5337 seconds
# Epoch 3/10 | Batch 74 | Time diff from previous batch 7.4747 seconds
# Epoch 3/10 | Batch 75 | Time diff from previous batch 7.4810 seconds
# Epoch 3/10 | Batch 76 | Time diff from previous batch 7.5553 seconds
# Epoch 3/10 | Batch 77 | Time diff from previous batch 7.5111 seconds
# Epoch 3/10 | Batch 78 | Time diff from previous batch 7.5631 seconds
# Epoch 3/10 | Batch 79 | Time diff from previous batch 7.5153 seconds
# Epoch 3/10 | Batch 80
# Time 51.88072991371155
# Running Training Loss: 1.224
# Running Training Accuracy: 69.84%
# Validation Loss: 0.777
# Validation Accuracy: 80.65%
# Epoch 3/10 | Batch 80 | Time diff from previous batch 52.2413 seconds
# Epoch 3/10 | Batch 81 | Time diff from previous batch 7.4877 seconds
# Epoch 3/10 | Batch 82 | Time diff from previous batch 7.6048 seconds
# Epoch 3/10 | Batch 83 | Time diff from previous batch 7.5505 seconds
# Epoch 3/10 | Batch 84 | Time diff from previous batch 7.4564 seconds
# Epoch 3/10 | Batch 85 | Time diff from previous batch 7.4593 seconds
# Epoch 3/10 | Batch 86 | Time diff from previous batch 7.5403 seconds
# Epoch 3/10 | Batch 87 | Time diff from previous batch 7.4632 seconds
# Epoch 3/10 | Batch 88 | Time diff from previous batch 7.4701 seconds
# Epoch 3/10 | Batch 89 | Time diff from previous batch 7.5537 seconds
# Epoch 3/10 | Batch 90 | Time diff from previous batch 7.5337 seconds
# Epoch 3/10 | Batch 91 | Time diff from previous batch 7.5932 seconds
# Epoch 3/10 | Batch 92 | Time diff from previous batch 7.6191 seconds
# Epoch 3/10 | Batch 93 | Time diff from previous batch 7.5805 seconds
# Epoch 3/10 | Batch 94 | Time diff from previous batch 7.4725 seconds
# Epoch 3/10 | Batch 95 | Time diff from previous batch 7.4803 seconds
# Epoch 3/10 | Batch 96 | Time diff from previous batch 7.5380 seconds
# Epoch 3/10 | Batch 97 | Time diff from previous batch 7.4641 seconds
# Epoch 3/10 | Batch 98 | Time diff from previous batch 7.5677 seconds
# Epoch 3/10 | Batch 99 | Time diff from previous batch 7.5788 seconds
# Epoch 3/10 | Batch 100
# Time 52.008782386779785
# Running Training Loss: 1.274
# Running Training Accuracy: 68.52%
# Validation Loss: 0.856
# Validation Accuracy: 77.07%
# Epoch 3/10 | Batch 100 | Time diff from previous batch 52.3735 seconds
# Epoch 3/10 | Batch 101 | Time diff from previous batch 7.4406 seconds
# Epoch 3/10 | Batch 102 | Time diff from previous batch 7.3279 seconds
# Epoch 4/10 | Batch 0 | Time diff from previous batch 1.7306 seconds
# Epoch 4/10 | Batch 1 | Time diff from previous batch 7.5818 seconds
# Epoch 4/10 | Batch 2 | Time diff from previous batch 7.5014 seconds
# Epoch 4/10 | Batch 3 | Time diff from previous batch 7.5257 seconds
# Epoch 4/10 | Batch 4 | Time diff from previous batch 7.5099 seconds
# Epoch 4/10 | Batch 5 | Time diff from previous batch 7.4706 seconds
# Epoch 4/10 | Batch 6 | Time diff from previous batch 7.4287 seconds
# Epoch 4/10 | Batch 7 | Time diff from previous batch 7.4045 seconds
# Epoch 4/10 | Batch 8 | Time diff from previous batch 7.4151 seconds
# Epoch 4/10 | Batch 9 | Time diff from previous batch 7.4746 seconds
# Epoch 4/10 | Batch 10 | Time diff from previous batch 7.4152 seconds
# Epoch 4/10 | Batch 11 | Time diff from previous batch 7.4317 seconds
# Epoch 4/10 | Batch 12 | Time diff from previous batch 7.4092 seconds
# Epoch 4/10 | Batch 13 | Time diff from previous batch 7.4514 seconds
# Epoch 4/10 | Batch 14 | Time diff from previous batch 7.4186 seconds
# Epoch 4/10 | Batch 15 | Time diff from previous batch 7.4360 seconds
# Epoch 4/10 | Batch 16 | Time diff from previous batch 7.4338 seconds
# Epoch 4/10 | Batch 17 | Time diff from previous batch 7.4495 seconds
# Epoch 4/10 | Batch 18 | Time diff from previous batch 7.4267 seconds
# Epoch 4/10 | Batch 19 | Time diff from previous batch 7.3985 seconds
# Epoch 4/10 | Batch 20
# Time 52.077781438827515
# Running Training Loss: 1.352
# Running Training Accuracy: 80.23%
# Validation Loss: 0.839
# Validation Accuracy: 79.26%
# Epoch 4/10 | Batch 20 | Time diff from previous batch 52.4071 seconds
# Epoch 4/10 | Batch 21 | Time diff from previous batch 7.4234 seconds
# Epoch 4/10 | Batch 22 | Time diff from previous batch 7.5108 seconds
# Epoch 4/10 | Batch 23 | Time diff from previous batch 7.4425 seconds
# Epoch 4/10 | Batch 24 | Time diff from previous batch 7.4537 seconds
# Epoch 4/10 | Batch 25 | Time diff from previous batch 7.5154 seconds
# Epoch 4/10 | Batch 26 | Time diff from previous batch 7.5881 seconds
# Epoch 4/10 | Batch 27 | Time diff from previous batch 7.4681 seconds
# Epoch 4/10 | Batch 28 | Time diff from previous batch 7.5657 seconds
# Epoch 4/10 | Batch 29 | Time diff from previous batch 7.4318 seconds
# Epoch 4/10 | Batch 30 | Time diff from previous batch 7.4711 seconds
# Epoch 4/10 | Batch 31 | Time diff from previous batch 7.4328 seconds
# Epoch 4/10 | Batch 32 | Time diff from previous batch 7.4357 seconds
# Epoch 4/10 | Batch 33 | Time diff from previous batch 7.4062 seconds
# Epoch 4/10 | Batch 34 | Time diff from previous batch 7.4388 seconds
# Epoch 4/10 | Batch 35 | Time diff from previous batch 7.5385 seconds
# Epoch 4/10 | Batch 36 | Time diff from previous batch 7.4257 seconds
# Epoch 4/10 | Batch 37 | Time diff from previous batch 7.4824 seconds
# Epoch 4/10 | Batch 38 | Time diff from previous batch 7.5922 seconds
# Epoch 4/10 | Batch 39 | Time diff from previous batch 7.4298 seconds
# Epoch 4/10 | Batch 40
# Time 51.9167799949646
# Running Training Loss: 1.086
# Running Training Accuracy: 71.56%
# Validation Loss: 0.697
# Validation Accuracy: 80.70%
# Epoch 4/10 | Batch 40 | Time diff from previous batch 52.2479 seconds
# Epoch 4/10 | Batch 41 | Time diff from previous batch 7.5024 seconds
# Epoch 4/10 | Batch 42 | Time diff from previous batch 7.4102 seconds
# Epoch 4/10 | Batch 43 | Time diff from previous batch 7.5162 seconds
# Epoch 4/10 | Batch 44 | Time diff from previous batch 7.4101 seconds
# Epoch 4/10 | Batch 45 | Time diff from previous batch 7.4525 seconds
# Epoch 4/10 | Batch 46 | Time diff from previous batch 7.4082 seconds
# Epoch 4/10 | Batch 47 | Time diff from previous batch 7.5107 seconds
# Epoch 4/10 | Batch 48 | Time diff from previous batch 7.4362 seconds
# Epoch 4/10 | Batch 49 | Time diff from previous batch 7.4395 seconds
# Epoch 4/10 | Batch 50 | Time diff from previous batch 7.4686 seconds
# Epoch 4/10 | Batch 51 | Time diff from previous batch 7.4602 seconds
# Epoch 4/10 | Batch 52 | Time diff from previous batch 7.4786 seconds
# Epoch 4/10 | Batch 53 | Time diff from previous batch 7.5307 seconds
# Epoch 4/10 | Batch 54 | Time diff from previous batch 7.5551 seconds
# Epoch 4/10 | Batch 55 | Time diff from previous batch 7.5494 seconds
# Epoch 4/10 | Batch 56 | Time diff from previous batch 7.5312 seconds
# Epoch 4/10 | Batch 57 | Time diff from previous batch 7.4723 seconds
# Epoch 4/10 | Batch 58 | Time diff from previous batch 7.4140 seconds
# Epoch 4/10 | Batch 59 | Time diff from previous batch 7.4815 seconds
# Epoch 4/10 | Batch 60
# Time 51.6941659450531
# Running Training Loss: 1.273
# Running Training Accuracy: 68.36%
# Validation Loss: 0.859
# Validation Accuracy: 78.93%
# Epoch 4/10 | Batch 60 | Time diff from previous batch 52.0384 seconds
# Epoch 4/10 | Batch 61 | Time diff from previous batch 7.4747 seconds
# Epoch 4/10 | Batch 62 | Time diff from previous batch 7.4211 seconds
# Epoch 4/10 | Batch 63 | Time diff from previous batch 7.4229 seconds
# Epoch 4/10 | Batch 64 | Time diff from previous batch 7.4313 seconds
# Epoch 4/10 | Batch 65 | Time diff from previous batch 7.4437 seconds
# Epoch 4/10 | Batch 66 | Time diff from previous batch 7.5321 seconds
# Epoch 4/10 | Batch 67 | Time diff from previous batch 7.4309 seconds
# Epoch 4/10 | Batch 68 | Time diff from previous batch 7.5317 seconds
# Epoch 4/10 | Batch 69 | Time diff from previous batch 7.4396 seconds
# Epoch 4/10 | Batch 70 | Time diff from previous batch 7.4457 seconds
# Epoch 4/10 | Batch 71 | Time diff from previous batch 7.4161 seconds
# Epoch 4/10 | Batch 72 | Time diff from previous batch 7.4111 seconds
# Epoch 4/10 | Batch 73 | Time diff from previous batch 7.4486 seconds
# Epoch 4/10 | Batch 74 | Time diff from previous batch 7.5298 seconds
# Epoch 4/10 | Batch 75 | Time diff from previous batch 7.5427 seconds
# Epoch 4/10 | Batch 76 | Time diff from previous batch 7.5398 seconds
# Epoch 4/10 | Batch 77 | Time diff from previous batch 7.4695 seconds
# Epoch 4/10 | Batch 78 | Time diff from previous batch 7.4236 seconds
# Epoch 4/10 | Batch 79 | Time diff from previous batch 7.5213 seconds
# Epoch 4/10 | Batch 80
# Time 51.740797996520996
# Running Training Loss: 1.260
# Running Training Accuracy: 69.45%
# Validation Loss: 0.798
# Validation Accuracy: 80.58%
# Epoch 4/10 | Batch 80 | Time diff from previous batch 52.0633 seconds
# Epoch 4/10 | Batch 81 | Time diff from previous batch 7.4878 seconds
# Epoch 4/10 | Batch 82 | Time diff from previous batch 7.5277 seconds
# Epoch 4/10 | Batch 83 | Time diff from previous batch 7.4869 seconds
# Epoch 4/10 | Batch 84 | Time diff from previous batch 7.5445 seconds
# Epoch 4/10 | Batch 85 | Time diff from previous batch 7.4373 seconds
# Epoch 4/10 | Batch 86 | Time diff from previous batch 7.4976 seconds
# Epoch 4/10 | Batch 87 | Time diff from previous batch 7.4262 seconds
# Epoch 4/10 | Batch 88 | Time diff from previous batch 7.4105 seconds
# Epoch 4/10 | Batch 89 | Time diff from previous batch 7.4980 seconds
# Epoch 4/10 | Batch 90 | Time diff from previous batch 7.4228 seconds
# Epoch 4/10 | Batch 91 | Time diff from previous batch 7.4318 seconds
# Epoch 4/10 | Batch 92 | Time diff from previous batch 7.4299 seconds
# Epoch 4/10 | Batch 93 | Time diff from previous batch 7.4451 seconds
# Epoch 4/10 | Batch 94 | Time diff from previous batch 7.4403 seconds
# Epoch 4/10 | Batch 95 | Time diff from previous batch 7.4275 seconds
# Epoch 4/10 | Batch 96 | Time diff from previous batch 7.4239 seconds
# Epoch 4/10 | Batch 97 | Time diff from previous batch 7.4711 seconds
# Epoch 4/10 | Batch 98 | Time diff from previous batch 7.5141 seconds
# Epoch 4/10 | Batch 99 | Time diff from previous batch 7.5185 seconds
# Epoch 4/10 | Batch 100
# Time 51.952245473861694
# Running Training Loss: 1.201
# Running Training Accuracy: 69.84%
# Validation Loss: 0.903
# Validation Accuracy: 77.55%
# Epoch 4/10 | Batch 100 | Time diff from previous batch 52.2883 seconds
# Epoch 4/10 | Batch 101 | Time diff from previous batch 7.4857 seconds
# Epoch 4/10 | Batch 102 | Time diff from previous batch 7.2406 seconds
# Epoch 5/10 | Batch 0 | Time diff from previous batch 1.8279 seconds
# Epoch 5/10 | Batch 1 | Time diff from previous batch 7.5396 seconds
# Epoch 5/10 | Batch 2 | Time diff from previous batch 7.4227 seconds
# Epoch 5/10 | Batch 3 | Time diff from previous batch 7.4335 seconds
# Epoch 5/10 | Batch 4 | Time diff from previous batch 7.3843 seconds
# Epoch 5/10 | Batch 5 | Time diff from previous batch 7.4367 seconds
# Epoch 5/10 | Batch 6 | Time diff from previous batch 7.4925 seconds
# Epoch 5/10 | Batch 7 | Time diff from previous batch 7.4431 seconds
# Epoch 5/10 | Batch 8 | Time diff from previous batch 7.5029 seconds
# Epoch 5/10 | Batch 9 | Time diff from previous batch 7.5035 seconds
# Epoch 5/10 | Batch 10 | Time diff from previous batch 7.4425 seconds
# Epoch 5/10 | Batch 11 | Time diff from previous batch 7.5327 seconds
# Epoch 5/10 | Batch 12 | Time diff from previous batch 7.5391 seconds
# Epoch 5/10 | Batch 13 | Time diff from previous batch 7.5140 seconds
# Epoch 5/10 | Batch 14 | Time diff from previous batch 7.4489 seconds
# Epoch 5/10 | Batch 15 | Time diff from previous batch 7.4152 seconds
# Epoch 5/10 | Batch 16 | Time diff from previous batch 7.5721 seconds
# Epoch 5/10 | Batch 17 | Time diff from previous batch 7.4603 seconds
# Epoch 5/10 | Batch 18 | Time diff from previous batch 7.4199 seconds
# Epoch 5/10 | Batch 19 | Time diff from previous batch 7.4176 seconds
# Epoch 5/10 | Batch 20
# Time 51.94116187095642
# Running Training Loss: 1.312
# Running Training Accuracy: 84.04%
# Validation Loss: 0.760
# Validation Accuracy: 81.06%
# Epoch 5/10 | Batch 20 | Time diff from previous batch 52.2586 seconds
# Epoch 5/10 | Batch 21 | Time diff from previous batch 7.4293 seconds
# Epoch 5/10 | Batch 22 | Time diff from previous batch 7.4476 seconds
# Epoch 5/10 | Batch 23 | Time diff from previous batch 7.4881 seconds
# Epoch 5/10 | Batch 24 | Time diff from previous batch 7.4828 seconds
# Epoch 5/10 | Batch 25 | Time diff from previous batch 7.5228 seconds
# Epoch 5/10 | Batch 26 | Time diff from previous batch 7.5007 seconds
# Epoch 5/10 | Batch 27 | Time diff from previous batch 7.4619 seconds
# Epoch 5/10 | Batch 28 | Time diff from previous batch 7.4702 seconds
# Epoch 5/10 | Batch 29 | Time diff from previous batch 7.5024 seconds
# Epoch 5/10 | Batch 30 | Time diff from previous batch 7.3916 seconds
# Epoch 5/10 | Batch 31 | Time diff from previous batch 7.3851 seconds
# Epoch 5/10 | Batch 32 | Time diff from previous batch 7.4881 seconds
# Epoch 5/10 | Batch 33 | Time diff from previous batch 7.4308 seconds
# Epoch 5/10 | Batch 34 | Time diff from previous batch 7.4743 seconds
# Epoch 5/10 | Batch 35 | Time diff from previous batch 7.4206 seconds
# Epoch 5/10 | Batch 36 | Time diff from previous batch 7.4809 seconds
# Epoch 5/10 | Batch 37 | Time diff from previous batch 7.4516 seconds
# Epoch 5/10 | Batch 38 | Time diff from previous batch 7.5074 seconds
# Epoch 5/10 | Batch 39 | Time diff from previous batch 7.5364 seconds
# Epoch 5/10 | Batch 40
# Time 52.29586863517761
# Running Training Loss: 1.172
# Running Training Accuracy: 72.50%
# Validation Loss: 0.889
# Validation Accuracy: 78.78%
# Epoch 5/10 | Batch 40 | Time diff from previous batch 52.6265 seconds
# Epoch 5/10 | Batch 41 | Time diff from previous batch 7.4138 seconds
# Epoch 5/10 | Batch 42 | Time diff from previous batch 7.4167 seconds
# Epoch 5/10 | Batch 43 | Time diff from previous batch 7.4499 seconds
# Epoch 5/10 | Batch 44 | Time diff from previous batch 7.4141 seconds
# Epoch 5/10 | Batch 45 | Time diff from previous batch 7.4293 seconds
# Epoch 5/10 | Batch 46 | Time diff from previous batch 7.4393 seconds
# Epoch 5/10 | Batch 47 | Time diff from previous batch 7.4517 seconds
# Epoch 5/10 | Batch 48 | Time diff from previous batch 7.4119 seconds
# Epoch 5/10 | Batch 49 | Time diff from previous batch 7.4183 seconds
# Epoch 5/10 | Batch 50 | Time diff from previous batch 7.4384 seconds
# Epoch 5/10 | Batch 51 | Time diff from previous batch 7.4577 seconds
# Epoch 5/10 | Batch 52 | Time diff from previous batch 7.4166 seconds
# Epoch 5/10 | Batch 53 | Time diff from previous batch 7.4408 seconds
# Epoch 5/10 | Batch 54 | Time diff from previous batch 7.4141 seconds
# Epoch 5/10 | Batch 55 | Time diff from previous batch 7.4357 seconds
# Epoch 5/10 | Batch 56 | Time diff from previous batch 7.4132 seconds
# Epoch 5/10 | Batch 57 | Time diff from previous batch 7.4088 seconds
# Epoch 5/10 | Batch 58 | Time diff from previous batch 7.4155 seconds
# Epoch 5/10 | Batch 59 | Time diff from previous batch 7.4078 seconds
# Epoch 5/10 | Batch 60
# Time 51.764731645584106
# Running Training Loss: 1.216
# Running Training Accuracy: 70.39%
# Validation Loss: 0.779
# Validation Accuracy: 80.25%
# Epoch 5/10 | Batch 60 | Time diff from previous batch 52.0943 seconds
# Epoch 5/10 | Batch 61 | Time diff from previous batch 7.4138 seconds
# Epoch 5/10 | Batch 62 | Time diff from previous batch 7.4387 seconds
# Epoch 5/10 | Batch 63 | Time diff from previous batch 7.4037 seconds
# Epoch 5/10 | Batch 64 | Time diff from previous batch 7.5696 seconds
# Epoch 5/10 | Batch 65 | Time diff from previous batch 7.4238 seconds
# Epoch 5/10 | Batch 66 | Time diff from previous batch 7.4555 seconds
# Epoch 5/10 | Batch 67 | Time diff from previous batch 7.5267 seconds
# Epoch 5/10 | Batch 68 | Time diff from previous batch 7.5691 seconds
# Epoch 5/10 | Batch 69 | Time diff from previous batch 7.4838 seconds
# Epoch 5/10 | Batch 70 | Time diff from previous batch 7.4436 seconds
# Epoch 5/10 | Batch 71 | Time diff from previous batch 7.4318 seconds
# Epoch 5/10 | Batch 72 | Time diff from previous batch 7.4631 seconds
# Epoch 5/10 | Batch 73 | Time diff from previous batch 7.4329 seconds
# Epoch 5/10 | Batch 74 | Time diff from previous batch 7.4444 seconds
# Epoch 5/10 | Batch 75 | Time diff from previous batch 7.4233 seconds
# Epoch 5/10 | Batch 76 | Time diff from previous batch 7.4600 seconds
# Epoch 5/10 | Batch 77 | Time diff from previous batch 7.5540 seconds
# Epoch 5/10 | Batch 78 | Time diff from previous batch 7.5379 seconds
# Epoch 5/10 | Batch 79 | Time diff from previous batch 7.4858 seconds
# Epoch 5/10 | Batch 80
# Time 51.75106334686279
# Running Training Loss: 1.159
# Running Training Accuracy: 71.72%
# Validation Loss: 0.711
# Validation Accuracy: 81.88%
# Epoch 5/10 | Batch 80 | Time diff from previous batch 52.0636 seconds
# Epoch 5/10 | Batch 81 | Time diff from previous batch 7.5221 seconds
# Epoch 5/10 | Batch 82 | Time diff from previous batch 7.4544 seconds
# Epoch 5/10 | Batch 83 | Time diff from previous batch 7.4111 seconds
# Epoch 5/10 | Batch 84 | Time diff from previous batch 7.5057 seconds
# Epoch 5/10 | Batch 85 | Time diff from previous batch 7.5137 seconds
# Epoch 5/10 | Batch 86 | Time diff from previous batch 7.5144 seconds
# Epoch 5/10 | Batch 87 | Time diff from previous batch 7.4800 seconds
# Epoch 5/10 | Batch 88 | Time diff from previous batch 7.4412 seconds
# Epoch 5/10 | Batch 89 | Time diff from previous batch 7.5335 seconds
# Epoch 5/10 | Batch 90 | Time diff from previous batch 7.4363 seconds
# Epoch 5/10 | Batch 91 | Time diff from previous batch 7.4156 seconds
# Epoch 5/10 | Batch 92 | Time diff from previous batch 7.5089 seconds
# Epoch 5/10 | Batch 93 | Time diff from previous batch 7.4286 seconds
# Epoch 5/10 | Batch 94 | Time diff from previous batch 7.5099 seconds
# Epoch 5/10 | Batch 95 | Time diff from previous batch 7.4204 seconds
# Epoch 5/10 | Batch 96 | Time diff from previous batch 7.3963 seconds
# Epoch 5/10 | Batch 97 | Time diff from previous batch 7.4783 seconds
# Epoch 5/10 | Batch 98 | Time diff from previous batch 7.4044 seconds
# Epoch 5/10 | Batch 99 | Time diff from previous batch 7.3772 seconds
# Epoch 5/10 | Batch 100
# Time 51.84931826591492
# Running Training Loss: 1.117
# Running Training Accuracy: 73.20%
# Validation Loss: 0.830
# Validation Accuracy: 79.53%
# Epoch 5/10 | Batch 100 | Time diff from previous batch 52.1642 seconds
# Epoch 5/10 | Batch 101 | Time diff from previous batch 7.4748 seconds
# Epoch 5/10 | Batch 102 | Time diff from previous batch 7.3406 seconds
# Epoch 6/10 | Batch 0 | Time diff from previous batch 1.7280 seconds
# Epoch 6/10 | Batch 1 | Time diff from previous batch 7.5141 seconds
# Epoch 6/10 | Batch 2 | Time diff from previous batch 7.4248 seconds
# Epoch 6/10 | Batch 3 | Time diff from previous batch 7.4358 seconds
# Epoch 6/10 | Batch 4 | Time diff from previous batch 7.4925 seconds
# Epoch 6/10 | Batch 5 | Time diff from previous batch 7.4338 seconds
# Epoch 6/10 | Batch 6 | Time diff from previous batch 7.5399 seconds
# Epoch 6/10 | Batch 7 | Time diff from previous batch 7.5297 seconds
# Epoch 6/10 | Batch 8 | Time diff from previous batch 7.5945 seconds
# Epoch 6/10 | Batch 9 | Time diff from previous batch 7.4128 seconds
# Epoch 6/10 | Batch 10 | Time diff from previous batch 7.4092 seconds
# Epoch 6/10 | Batch 11 | Time diff from previous batch 7.6339 seconds
# Epoch 6/10 | Batch 12 | Time diff from previous batch 7.7082 seconds
# Epoch 6/10 | Batch 13 | Time diff from previous batch 7.4426 seconds
# Epoch 6/10 | Batch 14 | Time diff from previous batch 7.4198 seconds
# Epoch 6/10 | Batch 15 | Time diff from previous batch 7.4671 seconds
# Epoch 6/10 | Batch 16 | Time diff from previous batch 7.4545 seconds
# Epoch 6/10 | Batch 17 | Time diff from previous batch 7.5531 seconds
# Epoch 6/10 | Batch 18 | Time diff from previous batch 7.4025 seconds
# Epoch 6/10 | Batch 19 | Time diff from previous batch 7.4248 seconds
# Epoch 6/10 | Batch 20
# Time 52.283297300338745
# Running Training Loss: 1.207
# Running Training Accuracy: 85.78%
# Validation Loss: 0.709
# Validation Accuracy: 82.24%
# Epoch 6/10 | Batch 20 | Time diff from previous batch 52.6032 seconds
# Epoch 6/10 | Batch 21 | Time diff from previous batch 7.4951 seconds
# Epoch 6/10 | Batch 22 | Time diff from previous batch 7.4248 seconds
# Epoch 6/10 | Batch 23 | Time diff from previous batch 7.4465 seconds
# Epoch 6/10 | Batch 24 | Time diff from previous batch 7.4905 seconds
# Epoch 6/10 | Batch 25 | Time diff from previous batch 7.4126 seconds
# Epoch 6/10 | Batch 26 | Time diff from previous batch 7.5202 seconds
# Epoch 6/10 | Batch 27 | Time diff from previous batch 7.5391 seconds
# Epoch 6/10 | Batch 28 | Time diff from previous batch 7.5546 seconds
# Epoch 6/10 | Batch 29 | Time diff from previous batch 7.5192 seconds
# Epoch 6/10 | Batch 30 | Time diff from previous batch 7.4904 seconds
# Epoch 6/10 | Batch 31 | Time diff from previous batch 7.3987 seconds
# Epoch 6/10 | Batch 32 | Time diff from previous batch 7.5149 seconds
# Epoch 6/10 | Batch 33 | Time diff from previous batch 7.5683 seconds
# Epoch 6/10 | Batch 34 | Time diff from previous batch 7.4173 seconds
# Epoch 6/10 | Batch 35 | Time diff from previous batch 7.4416 seconds
# Epoch 6/10 | Batch 36 | Time diff from previous batch 7.4083 seconds
# Epoch 6/10 | Batch 37 | Time diff from previous batch 7.6551 seconds
# Epoch 6/10 | Batch 38 | Time diff from previous batch 7.5252 seconds
# Epoch 6/10 | Batch 39 | Time diff from previous batch 7.4688 seconds
# Epoch 6/10 | Batch 40
# Time 51.93640494346619
# Running Training Loss: 1.121
# Running Training Accuracy: 73.67%
# Validation Loss: 0.680
# Validation Accuracy: 83.71%
# Epoch 6/10 | Batch 40 | Time diff from previous batch 52.2625 seconds
# Epoch 6/10 | Batch 41 | Time diff from previous batch 7.5308 seconds
# Epoch 6/10 | Batch 42 | Time diff from previous batch 7.5010 seconds
# Epoch 6/10 | Batch 43 | Time diff from previous batch 7.4501 seconds
# Epoch 6/10 | Batch 44 | Time diff from previous batch 7.4878 seconds
# Epoch 6/10 | Batch 45 | Time diff from previous batch 7.5298 seconds
# Epoch 6/10 | Batch 46 | Time diff from previous batch 7.5348 seconds
# Epoch 6/10 | Batch 47 | Time diff from previous batch 7.5031 seconds
# Epoch 6/10 | Batch 48 | Time diff from previous batch 7.5448 seconds
# Epoch 6/10 | Batch 49 | Time diff from previous batch 7.4051 seconds
# Epoch 6/10 | Batch 50 | Time diff from previous batch 7.4047 seconds
# Epoch 6/10 | Batch 51 | Time diff from previous batch 7.4725 seconds
# Epoch 6/10 | Batch 52 | Time diff from previous batch 7.4079 seconds
# Epoch 6/10 | Batch 53 | Time diff from previous batch 7.4130 seconds
# Epoch 6/10 | Batch 54 | Time diff from previous batch 7.4863 seconds
# Epoch 6/10 | Batch 55 | Time diff from previous batch 7.4278 seconds
# Epoch 6/10 | Batch 56 | Time diff from previous batch 7.4084 seconds
# Epoch 6/10 | Batch 57 | Time diff from previous batch 7.4042 seconds
# Epoch 6/10 | Batch 58 | Time diff from previous batch 7.5016 seconds
# Epoch 6/10 | Batch 59 | Time diff from previous batch 7.4403 seconds
# Epoch 6/10 | Batch 60
# Time 51.653916120529175
# Running Training Loss: 1.099
# Running Training Accuracy: 72.97%
# Validation Loss: 0.840
# Validation Accuracy: 80.58%
# Epoch 6/10 | Batch 60 | Time diff from previous batch 51.9785 seconds
# Epoch 6/10 | Batch 61 | Time diff from previous batch 7.4122 seconds
# Epoch 6/10 | Batch 62 | Time diff from previous batch 7.4130 seconds
# Epoch 6/10 | Batch 63 | Time diff from previous batch 7.4164 seconds
# Epoch 6/10 | Batch 64 | Time diff from previous batch 7.4630 seconds
# Epoch 6/10 | Batch 65 | Time diff from previous batch 7.4220 seconds
# Epoch 6/10 | Batch 66 | Time diff from previous batch 7.4306 seconds
# Epoch 6/10 | Batch 67 | Time diff from previous batch 7.4152 seconds
# Epoch 6/10 | Batch 68 | Time diff from previous batch 7.4508 seconds
# Epoch 6/10 | Batch 69 | Time diff from previous batch 7.3938 seconds
# Epoch 6/10 | Batch 70 | Time diff from previous batch 7.4098 seconds
# Epoch 6/10 | Batch 71 | Time diff from previous batch 7.4346 seconds
# Epoch 6/10 | Batch 72 | Time diff from previous batch 7.4711 seconds
# Epoch 6/10 | Batch 73 | Time diff from previous batch 7.4098 seconds
# Epoch 6/10 | Batch 74 | Time diff from previous batch 7.4067 seconds
# Epoch 6/10 | Batch 75 | Time diff from previous batch 7.4339 seconds
# Epoch 6/10 | Batch 76 | Time diff from previous batch 7.4322 seconds
# Epoch 6/10 | Batch 77 | Time diff from previous batch 7.4188 seconds
# Epoch 6/10 | Batch 78 | Time diff from previous batch 7.4052 seconds
# Epoch 6/10 | Batch 79 | Time diff from previous batch 7.4168 seconds
# Epoch 6/10 | Batch 80
# Time 51.64523506164551
# Running Training Loss: 1.090
# Running Training Accuracy: 72.34%
# Validation Loss: 0.880
# Validation Accuracy: 81.64%
# Epoch 6/10 | Batch 80 | Time diff from previous batch 51.9647 seconds
# Epoch 6/10 | Batch 81 | Time diff from previous batch 7.4536 seconds
# Epoch 6/10 | Batch 82 | Time diff from previous batch 7.4246 seconds
# Epoch 6/10 | Batch 83 | Time diff from previous batch 7.4052 seconds
# Epoch 6/10 | Batch 84 | Time diff from previous batch 7.4081 seconds
# Epoch 6/10 | Batch 85 | Time diff from previous batch 7.4668 seconds
# Epoch 6/10 | Batch 86 | Time diff from previous batch 7.5095 seconds
# Epoch 6/10 | Batch 87 | Time diff from previous batch 7.5155 seconds
# Epoch 6/10 | Batch 88 | Time diff from previous batch 7.4127 seconds
# Epoch 6/10 | Batch 89 | Time diff from previous batch 7.4622 seconds
# Epoch 6/10 | Batch 90 | Time diff from previous batch 7.4112 seconds
# Epoch 6/10 | Batch 91 | Time diff from previous batch 7.4181 seconds
# Epoch 6/10 | Batch 92 | Time diff from previous batch 7.4029 seconds
# Epoch 6/10 | Batch 93 | Time diff from previous batch 7.4704 seconds
# Epoch 6/10 | Batch 94 | Time diff from previous batch 7.4203 seconds
# Epoch 6/10 | Batch 95 | Time diff from previous batch 7.4119 seconds
# Epoch 6/10 | Batch 96 | Time diff from previous batch 7.4112 seconds
# Epoch 6/10 | Batch 97 | Time diff from previous batch 7.4790 seconds
# Epoch 6/10 | Batch 98 | Time diff from previous batch 7.4222 seconds
# Epoch 6/10 | Batch 99 | Time diff from previous batch 7.3995 seconds
# Epoch 6/10 | Batch 100
# Time 51.64096260070801
# Running Training Loss: 1.222
# Running Training Accuracy: 72.19%
# Validation Loss: 0.864
# Validation Accuracy: 80.73%
# Epoch 6/10 | Batch 100 | Time diff from previous batch 51.9559 seconds
# Epoch 6/10 | Batch 101 | Time diff from previous batch 7.4104 seconds
# Epoch 6/10 | Batch 102 | Time diff from previous batch 7.2857 seconds
# Epoch 7/10 | Batch 0 | Time diff from previous batch 1.7110 seconds
# Epoch 7/10 | Batch 1 | Time diff from previous batch 7.4072 seconds
# Epoch 7/10 | Batch 2 | Time diff from previous batch 7.4112 seconds
# Epoch 7/10 | Batch 3 | Time diff from previous batch 7.4045 seconds
# Epoch 7/10 | Batch 4 | Time diff from previous batch 7.5224 seconds
# Epoch 7/10 | Batch 5 | Time diff from previous batch 7.4175 seconds
# Epoch 7/10 | Batch 6 | Time diff from previous batch 7.4212 seconds
# Epoch 7/10 | Batch 7 | Time diff from previous batch 7.4019 seconds
# ...
# Epoch 8/10 | Batch 102 | Time diff from previous batch 7.3013 seconds
# Epoch 9/10 | Batch 0 | Time diff from previous batch 1.7085 seconds
# Epoch 9/10 | Batch 1 | Time diff from previous batch 7.4258 seconds
# Epoch 9/10 | Batch 2 | Time diff from previous batch 7.5474 seconds
# Epoch 9/10 | Batch 3 | Time diff from previous batch 7.4772 seconds
# Epoch 9/10 | Batch 4 | Time diff from previous batch 7.4227 seconds
# Epoch 9/10 | Batch 5 | Time diff from previous batch 7.4196 seconds
# Epoch 9/10 | Batch 6 | Time diff from previous batch 7.4468 seconds
# Epoch 9/10 | Batch 7 | Time diff from previous batch 7.4897 seconds
# Epoch 9/10 | Batch 8 | Time diff from previous batch 7.4093 seconds
# Epoch 9/10 | Batch 9 | Time diff from previous batch 7.4125 seconds
# Epoch 9/10 | Batch 10 | Time diff from previous batch 7.4653 seconds
# Epoch 9/10 | Batch 11 | Time diff from previous batch 7.4411 seconds
# Epoch 9/10 | Batch 12 | Time diff from previous batch 7.4490 seconds
# Epoch 9/10 | Batch 13 | Time diff from previous batch 7.4044 seconds
# Epoch 9/10 | Batch 14 | Time diff from previous batch 7.4184 seconds
# Epoch 9/10 | Batch 15 | Time diff from previous batch 7.5212 seconds
# Epoch 9/10 | Batch 16 | Time diff from previous batch 7.4744 seconds
# Epoch 9/10 | Batch 17 | Time diff from previous batch 7.4142 seconds
# Epoch 9/10 | Batch 18 | Time diff from previous batch 7.4122 seconds
# Epoch 9/10 | Batch 19 | Time diff from previous batch 7.4095 seconds
# Epoch 9/10 | Batch 20
# Time 51.61985635757446
# Running Training Loss: 1.196
# Running Training Accuracy: 88.46%
# Validation Loss: 0.965
# Validation Accuracy: 79.67%
# Epoch 9/10 | Batch 20 | Time diff from previous batch 51.9295 seconds
# Epoch 9/10 | Batch 21 | Time diff from previous batch 7.4610 seconds
# Epoch 9/10 | Batch 22 | Time diff from previous batch 7.4210 seconds
# Epoch 9/10 | Batch 23 | Time diff from previous batch 7.4242 seconds
# Epoch 9/10 | Batch 24 | Time diff from previous batch 7.3964 seconds
# Epoch 9/10 | Batch 25 | Time diff from previous batch 7.4740 seconds
# Epoch 9/10 | Batch 26 | Time diff from previous batch 7.4240 seconds
# Epoch 9/10 | Batch 27 | Time diff from previous batch 7.4132 seconds
# Epoch 9/10 | Batch 28 | Time diff from previous batch 7.4100 seconds
# Epoch 9/10 | Batch 29 | Time diff from previous batch 7.4592 seconds
# Epoch 9/10 | Batch 30 | Time diff from previous batch 7.4415 seconds
# Epoch 9/10 | Batch 31 | Time diff from previous batch 7.5847 seconds
# Epoch 9/10 | Batch 32 | Time diff from previous batch 7.4268 seconds
# Epoch 9/10 | Batch 33 | Time diff from previous batch 7.4211 seconds
# Epoch 9/10 | Batch 34 | Time diff from previous batch 7.4278 seconds
# Epoch 9/10 | Batch 35 | Time diff from previous batch 7.4857 seconds
# Epoch 9/10 | Batch 36 | Time diff from previous batch 7.4505 seconds
# Epoch 9/10 | Batch 37 | Time diff from previous batch 7.4374 seconds
# Epoch 9/10 | Batch 38 | Time diff from previous batch 7.4246 seconds
# Epoch 9/10 | Batch 39 | Time diff from previous batch 7.4548 seconds
# Epoch 9/10 | Batch 40
# Time 51.676347732543945
# Running Training Loss: 0.942
# Running Training Accuracy: 77.19%
# Validation Loss: 0.897
# Validation Accuracy: 82.65%
# Epoch 9/10 | Batch 40 | Time diff from previous batch 51.9951 seconds
# Epoch 9/10 | Batch 41 | Time diff from previous batch 7.5275 seconds
# Epoch 9/10 | Batch 42 | Time diff from previous batch 7.5182 seconds
# Epoch 9/10 | Batch 43 | Time diff from previous batch 7.4581 seconds
# Epoch 9/10 | Batch 44 | Time diff from previous batch 7.4778 seconds
# Epoch 9/10 | Batch 45 | Time diff from previous batch 7.4702 seconds
# Epoch 9/10 | Batch 46 | Time diff from previous batch 7.4957 seconds
# Epoch 9/10 | Batch 47 | Time diff from previous batch 7.4390 seconds
# Epoch 9/10 | Batch 48 | Time diff from previous batch 7.4348 seconds
# Epoch 9/10 | Batch 49 | Time diff from previous batch 7.4102 seconds
# Epoch 9/10 | Batch 50 | Time diff from previous batch 7.4222 seconds
# Epoch 9/10 | Batch 51 | Time diff from previous batch 7.5081 seconds
# Epoch 9/10 | Batch 52 | Time diff from previous batch 7.5614 seconds
# Epoch 9/10 | Batch 53 | Time diff from previous batch 7.3962 seconds
# Epoch 9/10 | Batch 54 | Time diff from previous batch 7.5309 seconds
# Epoch 9/10 | Batch 55 | Time diff from previous batch 7.4220 seconds
# Epoch 9/10 | Batch 56 | Time diff from previous batch 7.4248 seconds
# Epoch 9/10 | Batch 57 | Time diff from previous batch 7.4495 seconds
# Epoch 9/10 | Batch 58 | Time diff from previous batch 7.4258 seconds
# Epoch 9/10 | Batch 59 | Time diff from previous batch 7.5034 seconds
# Epoch 9/10 | Batch 60
# Time 52.201040744781494
# Running Training Loss: 1.044
# Running Training Accuracy: 75.23%
# Validation Loss: 0.841
# Validation Accuracy: 80.34%
# Epoch 9/10 | Batch 60 | Time diff from previous batch 52.5450 seconds
# Epoch 9/10 | Batch 61 | Time diff from previous batch 7.6256 seconds
# Epoch 9/10 | Batch 62 | Time diff from previous batch 7.4937 seconds
# Epoch 9/10 | Batch 63 | Time diff from previous batch 7.4357 seconds
# Epoch 9/10 | Batch 64 | Time diff from previous batch 7.4426 seconds
# Epoch 9/10 | Batch 65 | Time diff from previous batch 7.4729 seconds
# Epoch 9/10 | Batch 66 | Time diff from previous batch 7.4897 seconds
# Epoch 9/10 | Batch 67 | Time diff from previous batch 7.5298 seconds
# Epoch 9/10 | Batch 68 | Time diff from previous batch 7.5537 seconds
# Epoch 9/10 | Batch 69 | Time diff from previous batch 7.5215 seconds
# Epoch 9/10 | Batch 70 | Time diff from previous batch 7.4299 seconds
# Epoch 9/10 | Batch 71 | Time diff from previous batch 7.4742 seconds
# Epoch 9/10 | Batch 72 | Time diff from previous batch 7.5069 seconds
# Epoch 9/10 | Batch 73 | Time diff from previous batch 7.4710 seconds
# Epoch 9/10 | Batch 74 | Time diff from previous batch 7.5045 seconds
# Epoch 9/10 | Batch 75 | Time diff from previous batch 7.5433 seconds
# Epoch 9/10 | Batch 76 | Time diff from previous batch 7.4515 seconds
# Epoch 9/10 | Batch 77 | Time diff from previous batch 7.5697 seconds
# Epoch 9/10 | Batch 78 | Time diff from previous batch 7.4418 seconds
# Epoch 9/10 | Batch 79 | Time diff from previous batch 7.4477 seconds
# Epoch 9/10 | Batch 80
# Time 52.060635805130005
# Running Training Loss: 1.029
# Running Training Accuracy: 75.70%
# Validation Loss: 0.955
# Validation Accuracy: 79.77%
# Epoch 9/10 | Batch 80 | Time diff from previous batch 52.5044 seconds
# Epoch 9/10 | Batch 81 | Time diff from previous batch 7.4998 seconds
# Epoch 9/10 | Batch 82 | Time diff from previous batch 7.5309 seconds
# Epoch 9/10 | Batch 83 | Time diff from previous batch 7.5111 seconds
# Epoch 9/10 | Batch 84 | Time diff from previous batch 7.5567 seconds
# Epoch 9/10 | Batch 85 | Time diff from previous batch 7.4810 seconds
# Epoch 9/10 | Batch 86 | Time diff from previous batch 7.5733 seconds
# Epoch 9/10 | Batch 87 | Time diff from previous batch 7.4505 seconds
# Epoch 9/10 | Batch 88 | Time diff from previous batch 7.5484 seconds
# Epoch 9/10 | Batch 89 | Time diff from previous batch 7.5067 seconds
# Epoch 9/10 | Batch 90 | Time diff from previous batch 7.4583 seconds
# Epoch 9/10 | Batch 91 | Time diff from previous batch 7.5290 seconds
# Epoch 9/10 | Batch 92 | Time diff from previous batch 7.5525 seconds
# Epoch 9/10 | Batch 93 | Time diff from previous batch 7.4966 seconds
# Epoch 9/10 | Batch 94 | Time diff from previous batch 7.5606 seconds
# Epoch 9/10 | Batch 95 | Time diff from previous batch 7.4496 seconds
# Epoch 9/10 | Batch 96 | Time diff from previous batch 7.5782 seconds
# Epoch 9/10 | Batch 97 | Time diff from previous batch 7.4964 seconds
# Epoch 9/10 | Batch 98 | Time diff from previous batch 7.5584 seconds
# Epoch 9/10 | Batch 99 | Time diff from previous batch 7.4827 seconds
# Epoch 9/10 | Batch 100
# Time 51.873289823532104
# Running Training Loss: 1.041
# Running Training Accuracy: 75.55%
# Validation Loss: 0.813
# Validation Accuracy: 83.80%
# Epoch 9/10 | Batch 100 | Time diff from previous batch 52.2144 seconds
# Epoch 9/10 | Batch 101 | Time diff from previous batch 7.4559 seconds
# Epoch 9/10 | Batch 102 | Time diff from previous batch 7.3245 seconds
# Epoch 10/10 | Batch 0 | Time diff from previous batch 1.7351 seconds
# Epoch 10/10 | Batch 1 | Time diff from previous batch 7.4319 seconds
# Epoch 10/10 | Batch 2 | Time diff from previous batch 7.5168 seconds
# Epoch 10/10 | Batch 3 | Time diff from previous batch 7.4855 seconds
# Epoch 10/10 | Batch 4 | Time diff from previous batch 7.4522 seconds
# Epoch 10/10 | Batch 5 | Time diff from previous batch 7.4346 seconds
# Epoch 10/10 | Batch 6 | Time diff from previous batch 7.4853 seconds
# Epoch 10/10 | Batch 7 | Time diff from previous batch 7.4980 seconds
# Epoch 10/10 | Batch 8 | Time diff from previous batch 7.4356 seconds
# Epoch 10/10 | Batch 9 | Time diff from previous batch 7.4394 seconds
# Epoch 10/10 | Batch 10 | Time diff from previous batch 7.4789 seconds
# Epoch 10/10 | Batch 11 | Time diff from previous batch 7.4668 seconds
# Epoch 10/10 | Batch 12 | Time diff from previous batch 7.5646 seconds
# Epoch 10/10 | Batch 13 | Time diff from previous batch 7.5326 seconds
# Epoch 10/10 | Batch 14 | Time diff from previous batch 7.5130 seconds
# Epoch 10/10 | Batch 15 | Time diff from previous batch 7.5210 seconds
# Epoch 10/10 | Batch 16 | Time diff from previous batch 7.5327 seconds
# Epoch 10/10 | Batch 17 | Time diff from previous batch 7.4885 seconds
# Epoch 10/10 | Batch 18 | Time diff from previous batch 7.5626 seconds
# Epoch 10/10 | Batch 19 | Time diff from previous batch 7.5666 seconds
# Epoch 10/10 | Batch 20
# Time 51.59649062156677
# Running Training Loss: 1.176
# Running Training Accuracy: 88.02%
# Validation Loss: 0.714
# Validation Accuracy: 82.76%
# Epoch 10/10 | Batch 20 | Time diff from previous batch 51.9216 seconds
# Epoch 10/10 | Batch 21 | Time diff from previous batch 7.5347 seconds
# Epoch 10/10 | Batch 22 | Time diff from previous batch 7.5082 seconds
# Epoch 10/10 | Batch 23 | Time diff from previous batch 7.4466 seconds
# Epoch 10/10 | Batch 24 | Time diff from previous batch 7.4518 seconds
# Epoch 10/10 | Batch 25 | Time diff from previous batch 7.4543 seconds
# Epoch 10/10 | Batch 26 | Time diff from previous batch 7.4641 seconds
# Epoch 10/10 | Batch 27 | Time diff from previous batch 7.5370 seconds
# Epoch 10/10 | Batch 28 | Time diff from previous batch 7.5740 seconds
# Epoch 10/10 | Batch 29 | Time diff from previous batch 7.5279 seconds
# Epoch 10/10 | Batch 30 | Time diff from previous batch 7.4721 seconds
# Epoch 10/10 | Batch 31 | Time diff from previous batch 7.4406 seconds
# Epoch 10/10 | Batch 32 | Time diff from previous batch 7.6196 seconds
# Epoch 10/10 | Batch 33 | Time diff from previous batch 7.5242 seconds
# Epoch 10/10 | Batch 34 | Time diff from previous batch 7.4474 seconds
# Epoch 10/10 | Batch 35 | Time diff from previous batch 7.4172 seconds
# Epoch 10/10 | Batch 36 | Time diff from previous batch 7.4551 seconds
# Epoch 10/10 | Batch 37 | Time diff from previous batch 7.4902 seconds
# Epoch 10/10 | Batch 38 | Time diff from previous batch 7.4860 seconds
# Epoch 10/10 | Batch 39 | Time diff from previous batch 7.5348 seconds
# Epoch 10/10 | Batch 40
# Time 51.983468532562256
# Running Training Loss: 0.886
# Running Training Accuracy: 77.73%
# Validation Loss: 0.902
# Validation Accuracy: 80.44%
# Epoch 10/10 | Batch 40 | Time diff from previous batch 52.3053 seconds
# Epoch 10/10 | Batch 41 | Time diff from previous batch 7.4830 seconds
# Epoch 10/10 | Batch 42 | Time diff from previous batch 7.4632 seconds
# Epoch 10/10 | Batch 43 | Time diff from previous batch 7.4858 seconds
# Epoch 10/10 | Batch 44 | Time diff from previous batch 7.4818 seconds
# Epoch 10/10 | Batch 45 | Time diff from previous batch 7.4526 seconds
# Epoch 10/10 | Batch 46 | Time diff from previous batch 7.4365 seconds
# Epoch 10/10 | Batch 47 | Time diff from previous batch 7.4320 seconds
# Epoch 10/10 | Batch 48 | Time diff from previous batch 7.5283 seconds
# Epoch 10/10 | Batch 49 | Time diff from previous batch 7.5086 seconds
# Epoch 10/10 | Batch 50 | Time diff from previous batch 7.5171 seconds
# Epoch 10/10 | Batch 51 | Time diff from previous batch 7.4380 seconds
# Epoch 10/10 | Batch 52 | Time diff from previous batch 7.4277 seconds
# Epoch 10/10 | Batch 53 | Time diff from previous batch 7.5200 seconds
# Epoch 10/10 | Batch 54 | Time diff from previous batch 7.4317 seconds
# Epoch 10/10 | Batch 55 | Time diff from previous batch 7.4297 seconds
# Epoch 10/10 | Batch 56 | Time diff from previous batch 7.4298 seconds
# Epoch 10/10 | Batch 57 | Time diff from previous batch 7.4389 seconds
# Epoch 10/10 | Batch 58 | Time diff from previous batch 7.4173 seconds
# Epoch 10/10 | Batch 59 | Time diff from previous batch 7.5089 seconds
# Epoch 10/10 | Batch 60
# Time 51.89534878730774
# Running Training Loss: 0.931
# Running Training Accuracy: 78.20%
# Validation Loss: 0.813
# Validation Accuracy: 82.29%
# Epoch 10/10 | Batch 60 | Time diff from previous batch 52.2067 seconds
# Epoch 10/10 | Batch 61 | Time diff from previous batch 7.4105 seconds
# Epoch 10/10 | Batch 62 | Time diff from previous batch 7.3985 seconds
# Epoch 10/10 | Batch 63 | Time diff from previous batch 7.4676 seconds
# Epoch 10/10 | Batch 64 | Time diff from previous batch 7.5141 seconds
# Epoch 10/10 | Batch 65 | Time diff from previous batch 7.5212 seconds
# Epoch 10/10 | Batch 66 | Time diff from previous batch 7.3975 seconds
# Epoch 10/10 | Batch 67 | Time diff from previous batch 7.4551 seconds
# Epoch 10/10 | Batch 68 | Time diff from previous batch 7.5034 seconds
# Epoch 10/10 | Batch 69 | Time diff from previous batch 7.4348 seconds
# Epoch 10/10 | Batch 70 | Time diff from previous batch 7.4072 seconds
# Epoch 10/10 | Batch 71 | Time diff from previous batch 7.4633 seconds
# Epoch 10/10 | Batch 72 | Time diff from previous batch 7.5326 seconds
# Epoch 10/10 | Batch 73 | Time diff from previous batch 7.4445 seconds
# Epoch 10/10 | Batch 74 | Time diff from previous batch 7.4161 seconds
# Epoch 10/10 | Batch 75 | Time diff from previous batch 7.5266 seconds
# Epoch 10/10 | Batch 76 | Time diff from previous batch 7.4184 seconds
# Epoch 10/10 | Batch 77 | Time diff from previous batch 7.4867 seconds
# Epoch 10/10 | Batch 78 | Time diff from previous batch 7.4664 seconds
# Epoch 10/10 | Batch 79 | Time diff from previous batch 7.4529 seconds
# Epoch 10/10 | Batch 80
# Time 51.75112247467041
# Running Training Loss: 1.077
# Running Training Accuracy: 75.39%
# Validation Loss: 0.788
# Validation Accuracy: 82.87%
# Epoch 10/10 | Batch 80 | Time diff from previous batch 52.0618 seconds
# Epoch 10/10 | Batch 81 | Time diff from previous batch 7.4178 seconds
# Epoch 10/10 | Batch 82 | Time diff from previous batch 7.5506 seconds
# Epoch 10/10 | Batch 83 | Time diff from previous batch 7.4102 seconds
# Epoch 10/10 | Batch 84 | Time diff from previous batch 7.5081 seconds
# Epoch 10/10 | Batch 85 | Time diff from previous batch 7.4916 seconds
# Epoch 10/10 | Batch 86 | Time diff from previous batch 7.5466 seconds
# Epoch 10/10 | Batch 87 | Time diff from previous batch 7.4514 seconds
# Epoch 10/10 | Batch 88 | Time diff from previous batch 7.5194 seconds
# Epoch 10/10 | Batch 89 | Time diff from previous batch 7.4382 seconds
# Epoch 10/10 | Batch 90 | Time diff from previous batch 7.4504 seconds
# Epoch 10/10 | Batch 91 | Time diff from previous batch 7.4026 seconds
# Epoch 10/10 | Batch 92 | Time diff from previous batch 7.4612 seconds
# Epoch 10/10 | Batch 93 | Time diff from previous batch 7.4943 seconds
# Epoch 10/10 | Batch 94 | Time diff from previous batch 7.4194 seconds
# Epoch 10/10 | Batch 95 | Time diff from previous batch 7.4328 seconds
# Epoch 10/10 | Batch 96 | Time diff from previous batch 7.5306 seconds
# Epoch 10/10 | Batch 97 | Time diff from previous batch 7.5011 seconds
# Epoch 10/10 | Batch 98 | Time diff from previous batch 7.5097 seconds
# Epoch 10/10 | Batch 99 | Time diff from previous batch 7.5078 seconds
# Epoch 10/10 | Batch 100
# Time 52.024152994155884
# Running Training Loss: 1.016
# Running Training Accuracy: 76.88%
# Validation Loss: 0.866
# Validation Accuracy: 83.40%
# Epoch 10/10 | Batch 100 | Time diff from previous batch 52.3378 seconds
# Epoch 10/10 | Batch 101 | Time diff from previous batch 7.5125 seconds
# Epoch 10/10 | Batch 102 | Time diff from previous batch 7.3512 seconds

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
#### Do validation on the test set

# defines test accuracy
test_accuracy = 0

start_time = time.time()
print('Validation started.')

for images,labels in test_loader:
    model.eval()
    images,labels = images.to(device),labels.to(device)
    log_ps = model.forward(images)
    ps = torch.exp(log_ps)
    top_ps,top_class = ps.topk(1,dim=1)
    matches = (top_class == labels.view(*top_class.shape)).type(torch.FloatTensor)
    accuracy = matches.mean()
    test_accuracy += accuracy

# Validation ended - show time cost of it together with accuracy of the validation.
end_time = time.time()
print('Validation ended.')
validation_time = end_time - start_time
print('Validation time: {:.0f}m {:.0f}s'.format(validation_time / 60, validation_time % 60))
    
print(f'Test Accuracy: {test_accuracy/len(test_loader)*100:.2f}%')
# Out:
# Validation started.
# Validation ended.
# Validation time: 1m 53s
# Test Accuracy: 83.69%

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# Save the checkpoint 
    
# Use current directory by default.
destination_directory = None
class_to_idx = image_datasets['train'].class_to_idx # improves label to name mapping

# saves the model's state_dict
def save_model(trained_model,destination_directory,model_arch,class_to_idx):
    # Defines model's checkpoint.
    # - General improvement :
    #       fixed values of neurons -> variables for each at the beginning of the file to easily manage changes.
    model_checkpoint = {'model_arch':model_arch, 
                    'clf_input':25088,
                    'clf_output':102,
                    'clf_hidden':4096,
                    'state_dict':trained_model.state_dict(),
                    'model_class_to_index':class_to_idx,
                    }
    
    if destination_directory: # If defined, we save in a specific directory.
        torch.save(model_checkpoint,destination_directory+"/"+model_arch+"_checkpoint.pth")
        print(f"{model_arch} successfully saved to {destination_directory}")
    else: # current directory
        torch.save(model_checkpoint,model_arch+"_checkpoint.pth")
        print(f"{model_arch} successfully saved to current directory as {model_arch}_checkpoint.pth")

# Call to save the model.
save_model(model,destination_directory,'vgg16',class_to_idx)
# Out:
# vgg16 successfully saved to current directory as vgg16_checkpoint.pth

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# Write a function that loads a checkpoint and rebuilds the model

checkpoint = 'vgg16_checkpoint.pth'

# function that accepts two arguments: filepath (location of checkpoint) and device(gpu/cpu)
def load_checkpoint(filepath,device):
    # loads the GPU when available
    if device=="gpu":
        map_location=lambda device, loc: device.cuda()
    else:
        map_location='cpu'
    # Redefines checkpoint by loading it.
    checkpoint = torch.load(f=filepath,map_location=map_location)

    # Get number of input units, output units, hidden units, and state_dict
    return checkpoint['model_arch'],checkpoint['clf_input'], checkpoint['clf_output'], checkpoint['clf_hidden'],checkpoint['state_dict'],checkpoint['model_class_to_index']

# loads the checkpoint and store needed parameters in appropiate variables.
model_arch,input_units, output_units, hidden_units, state_dict, class_to_idx = load_checkpoint(checkpoint,device)
model.load_state_dict(state_dict)
# Out:
# C:\Users\pablo\AppData\Local\Temp\ipykernel_20452\3143100032.py:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(f=filepath,map_location=map_location)
# <All keys matched successfully>

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
# Process a PIL image for use in a PyTorch model
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    processed_image = Image.open(image).convert('RGB') # open the image
    print(type(processed_image))
    resized_image = processed_image.resize((256, 256))
    width, height = resized_image.size   # Get dimensions of the resized image.
    
    # Crop the image's center.
    left = (width - 224)/2
    top = (height - 224)/2
    right = (width + 224)/2
    bottom = (height + 224)/2
    cropped_image = resized_image.crop((left, top, right, bottom))
    # Debugging & informative purposes.
    #print(f"Width: {width}, Height: {height}")
    #print(f"Crop Box: Left={left}, Top={top}, Right={right}, Bottom={bottom}")
    
    # Converts to tensor and apply normalization.
    transf_tens = transforms.ToTensor()
    transf_norm = transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225]) # mean, std
    tensor = transf_norm(transf_tens(cropped_image))
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  # mean and std
    ])
    tensor_image = transform(cropped_image)
    
    # Convert tensor result to numpy array.
    np_processed_image = tensor_image.numpy()
    return np_processed_image

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension but matplotlib assumes is the third dimension.
    image = image.transpose((1, 2, 0))
    
    # Undo preprocessing.
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 to avoid visualization issues.
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %%
from PIL import Image

# Random images selected to test with different cases the code.

#test_image = "./flowers/test/15/image_06351.jpg"
#test_image = "./flowers/test/17/image_03906.jpg"
test_image = "./flowers/test/56/image_02825.jpg"
#test_image = "./flowers/test/89/image_00699.jpg"

# Display original image.
original_image = Image.open(test_image)
original_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=752x500>

# %%
# Displays processed image.
imshow(process_image(test_image))
# Out:
# <class 'PIL.Image.Image'>
# Width: 256, Height: 256
# Crop Box: Left=16.0, Top=16.0, Right=240.0, Bottom=240.0
# <Axes: >

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
# Implement the code to predict the class from an image file

def class_to_label(file,classes):
    with open(file, 'r') as f:
        class_mapping =  json.load(f)
        
    labels = []
    for c in classes:
        labels.append(class_mapping[c])
    return labels

# Uses class_to_label() to map folder labels (1-102) to flower names.
idx_mapping = dict(map(reversed, class_to_idx.items()))

# Predicts the class of an image using out deep learning model. 
def predict(image_path, model,idx_mapping, topk, device):
    # defines preprocessed image
    pre_processed_image = torch.from_numpy(process_image(image_path))
    pre_processed_image = torch.unsqueeze(pre_processed_image,0).to(device).float()
    
    model.to(device)
    model.eval()
    
    log_ps = model.forward(pre_processed_image)
    ps = torch.exp(log_ps)
    top_ps,top_idx = ps.topk(topk,dim=1)
    list_ps = top_ps.tolist()[0]
    list_idx = top_idx.tolist()[0]
    classes = []
    model.train()
    
    for x in list_idx:
        classes.append(idx_mapping[x])
    return list_ps, classes

# Print out the probability output for the image selected and a given number of classes.
def print_predictions(probabilities, classes,image,category_names=None):
    print(image) # Image name is printed out, just informative.
    
    if category_names:
        labels = class_to_label(category_names,classes)
        for i,(ps,ls,cs) in enumerate(zip(probabilities,labels,classes),1):
            print(f'{i}) {ps*100:.2f}% {ls.title()} | Class No. {cs}')
    else:
        for i,(ps,cs) in enumerate(zip(probabilities,classes),1):
            print(f'{i}) {ps*100:.2f}% Class No. {cs} ')
    print('') 

probabilities,classes = predict(test_image,model,idx_mapping,5,device)

# Test the code and print out the predictions for 5 classes.
print_predictions(probabilities,classes,test_image.split('/')[-1],'cat_to_name.json')
# Out:
# <class 'PIL.Image.Image'>
# Width: 256, Height: 256
# Crop Box: Left=16.0, Top=16.0, Right=240.0, Bottom=240.0
# image_02825.jpg
# 1) 100.00% Bishop Of Llandaff | Class No. 56
# 2) 0.00% Petunia | Class No. 51
# 3) 0.00% Barbeton Daisy | Class No. 41
# 4) 0.00% Cyclamen | Class No. 88
# 5) 0.00% Wallflower | Class No. 46

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# Display an image along with the top 5 classes.

imshow(process_image(test_image)) # Show processed image.

# Uses matplotlib for showing the bar chart of probabilities.
plt.figure()
plt.barh(class_to_label('cat_to_name.json',classes),width=probabilities)
plt.title('Model Predictions')
plt.gca().invert_yaxis()
plt.show()
# Out:
# <class 'PIL.Image.Image'>
# Width: 256, Height: 256
# Crop Box: Left=16.0, Top=16.0, Right=240.0, Bottom=240.0
